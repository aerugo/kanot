# %% [markdown]
# # Import data from Conflicted Glossary

# %%
import pandas as pd

# Load the CSV files into DataFrames
codes_df = pd.read_csv('../_temp/glossary.csv')  # type: ignore
transcripts_df = pd.read_csv('../_temp/transcripts.csv')  # type: ignore

# Rename columns according to the provided mapping
codes_df = codes_df.rename(columns={
    'Glossary ID': 'code_id',
    'Term': 'term',
    'Description': 'description',
    'Type': 'type',
    'Read more': 'reference',
    'Lat/Long': 'coordinates'
})
codes_df = codes_df[['code_id', 'term', 'description', 'type', 'reference', 'coordinates']]

transcripts_df = transcripts_df.rename(columns={
    'Text ID': 'transcript_id',
    'Text': 'transcript_text',
    'Episode ID': 'episode_id',
    'Episode': 'episode_title',
    'Glossary IDs': 'code_ids'
})
# drop the columns that are not transcript_id, transcript_text, episode_id, episode_title, code_ids
transcripts_df = transcripts_df[['transcript_id', 'transcript_text', 'episode_id', 'episode_title', 'code_ids']]

transcripts_df['code_ids'] = transcripts_df['code_ids'].fillna('') # type: ignore

# create a dataframe with all unique episode_id and episode_title
episode_df = transcripts_df[['episode_id', 'episode_title']].drop_duplicates()

# create a dataframe with all unique glossary type
code_type_df = codes_df[['type']].drop_duplicates()
# rename the column to type_name
code_type_df = code_type_df.rename(columns={'type': 'type_name'})

# %%
# Create a new DataFrame annotations_df with columns transcript_id, code_id
annotations_df = pd.DataFrame(columns=['transcript_id', 'code_id'])

# Iterate over each row in transcripts_df and add rows to annotations_df
rows_to_add = []
for index, row in transcripts_df.iterrows():
    transcript_id = row['transcript_id']
    code_ids = row['code_ids'].split(';')
    for code_id in code_ids if code_ids != [''] else []:
        code_id = int(code_id)
        rows_to_add.append({'transcript_id': transcript_id, 'code_id': code_id})

transcripts_df.drop(columns=['code_ids'], inplace=True) # type: ignore

# Convert list of rows to DataFrame and concatenate
annotations_df = pd.concat([annotations_df, pd.DataFrame(rows_to_add)], ignore_index=True)

# Convert code_id to int
annotations_df['code_id'] = annotations_df['code_id'].astype(int)

# Add a column annotation_id to annotations_df
annotations_df['annotation_id'] = annotations_df.index

# %% [markdown]
# # Define Database

# %%
from kanot.db.schema import create_database, drop_database, CodeType, Code, Episode, Transcript, Annotation
from sqlalchemy import create_engine, Engine
from sqlalchemy.orm import sessionmaker

# Create a connection to the SQLite database
engine: Engine = create_engine('sqlite:///conflicted_glossary.db', echo=True)
MySession = sessionmaker(bind=engine)
session = MySession()

drop = False
if drop:
    # Drop all the tables in the database
    drop_database(engine)

# Create the tables in the database
create_database(engine)
# Out:
# 2024-07-12 15:33:31,885 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-12 15:33:31,885 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("code_types")
# 2024-07-12 15:33:31,886 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-12 15:33:31,886 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("codes")
# 2024-07-12 15:33:31,886 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-12 15:33:31,887 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("episodes")
# 2024-07-12 15:33:31,887 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-12 15:33:31,887 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("transcripts")
# 2024-07-12 15:33:31,887 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-12 15:33:31,888 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("annotations")
# 2024-07-12 15:33:31,888 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-12 15:33:31,888 INFO sqlalchemy.engine.Engine
# DROP TABLE annotations
# 2024-07-12 15:33:31,888 INFO sqlalchemy.engine.Engine [no key 0.00020s] ()
# 2024-07-12 15:33:31,890 INFO sqlalchemy.engine.Engine
# DROP TABLE transcripts
# 2024-07-12 15:33:31,890 INFO sqlalchemy.engine.Engine [no key 0.00015s] ()
# 2024-07-12 15:33:31,892 INFO sqlalchemy.engine.Engine
# DROP TABLE codes
# 2024-07-12 15:33:31,892 INFO sqlalchemy.engine.Engine [no key 0.00021s] ()
# 2024-07-12 15:33:31,892 INFO sqlalchemy.engine.Engine
# DROP TABLE episodes
# 2024-07-12 15:33:31,893 INFO sqlalchemy.engine.Engine [no key 0.00017s] ()
# 2024-07-12 15:33:31,893 INFO sqlalchemy.engine.Engine
# DROP TABLE code_types
# 2024-07-12 15:33:31,893 INFO sqlalchemy.engine.Engine [no key 0.00015s] ()
# 2024-07-12 15:33:31,894 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-12 15:33:31,894 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-12 15:33:31,894 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("code_types")
# 2024-07-12 15:33:31,894 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-12 15:33:31,895 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("code_types")
# 2024-07-12 15:33:31,895 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-12 15:33:31,895 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("codes")
# 2024-07-12 15:33:31,895 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-12 15:33:31,896 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("codes")
# 2024-07-12 15:33:31,896 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-12 15:33:31,896 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("episodes")
# 2024-07-12 15:33:31,896 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-12 15:33:31,897 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("episodes")
# 2024-07-12 15:33:31,897 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-12 15:33:31,897 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("transcripts")
# 2024-07-12 15:33:31,897 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-12 15:33:31,897 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("transcripts")
# 2024-07-12 15:33:31,898 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-12 15:33:31,898 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("annotations")
# 2024-07-12 15:33:31,898 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-12 15:33:31,898 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("annotations")
# 2024-07-12 15:33:31,899 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-12 15:33:31,899 INFO sqlalchemy.engine.Engine
# CREATE TABLE code_types (
# 	type_id INTEGER NOT NULL,
# 	type_name TEXT NOT NULL,
# 	PRIMARY KEY (type_id),
# 	UNIQUE (type_name)
# )
#
#
# 2024-07-12 15:33:31,899 INFO sqlalchemy.engine.Engine [no key 0.00026s] ()
# 2024-07-12 15:33:31,901 INFO sqlalchemy.engine.Engine
# CREATE TABLE episodes (
# 	episode_id VARCHAR NOT NULL,
# 	episode_title TEXT NOT NULL,
# 	PRIMARY KEY (episode_id),
# 	UNIQUE (episode_title)
# )
#
#
# 2024-07-12 15:33:31,901 INFO sqlalchemy.engine.Engine [no key 0.00023s] ()
# 2024-07-12 15:33:31,902 INFO sqlalchemy.engine.Engine
# CREATE TABLE codes (
# 	code_id INTEGER NOT NULL,
# 	term TEXT NOT NULL,
# 	description TEXT,
# 	type_id INTEGER,
# 	reference TEXT,
# 	coordinates TEXT,
# 	PRIMARY KEY (code_id),
# 	UNIQUE (term),
# 	FOREIGN KEY(type_id) REFERENCES code_types (type_id)
# )
#
#
# 2024-07-12 15:33:31,902 INFO sqlalchemy.engine.Engine [no key 0.00021s] ()
# 2024-07-12 15:33:31,904 INFO sqlalchemy.engine.Engine
# CREATE TABLE transcripts (
# 	transcript_id INTEGER NOT NULL,
# 	transcript_text TEXT,
# 	episode_id VARCHAR,
# 	PRIMARY KEY (transcript_id),
# 	FOREIGN KEY(episode_id) REFERENCES episodes (episode_id)
# )
#
#
# 2024-07-12 15:33:31,904 INFO sqlalchemy.engine.Engine [no key 0.00020s] ()
# 2024-07-12 15:33:31,905 INFO sqlalchemy.engine.Engine
# CREATE TABLE annotations (
# 	annotation_id INTEGER NOT NULL,
# 	transcript_id INTEGER,
# 	code_id INTEGER,
# 	PRIMARY KEY (annotation_id),
# 	CONSTRAINT _transcript_code_uc UNIQUE (transcript_id, code_id),
# 	FOREIGN KEY(transcript_id) REFERENCES transcripts (transcript_id),
# 	FOREIGN KEY(code_id) REFERENCES codes (code_id)
# )
#
#
# 2024-07-12 15:33:31,905 INFO sqlalchemy.engine.Engine [no key 0.00030s] ()
# 2024-07-12 15:33:31,906 INFO sqlalchemy.engine.Engine COMMIT

# %%
from sqlalchemy import func
from sqlalchemy.orm import Session
from sqlalchemy.ext.declarative import DeclarativeMeta
from sqlalchemy.exc import IntegrityError
from typing import Any, Hashable

# Define a function to insert data from a DataFrame
def insert_data(df: pd.DataFrame, model: DeclarativeMeta, session: Session) -> None:
    data: list[dict[Hashable, Any]] = df.to_dict(orient='records') # type: ignore
    
    try:
        session.bulk_insert_mappings(model, data) # type: ignore
        session.commit()
    except IntegrityError as e:
        print(f"Unique constraint violation: {e}")
        session.rollback()

# Insert data into the code_types table
insert_data(code_type_df, CodeType, session)

# Insert data into the codes table
insert_data(codes_df, Code, session)

# Insert data into the episodes table
insert_data(episode_df, Episode, session)

# Insert data into the transcripts table
insert_data(transcripts_df, Transcript, session)

# Insert data into the annotations table
insert_data(annotations_df, Annotation, session)

# Close the session
session.close()
# Out:
# 2024-07-12 15:33:31,918 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-12 15:33:31,924 INFO sqlalchemy.engine.Engine INSERT INTO code_types (type_name) VALUES (?)
# 2024-07-12 15:33:31,932 INFO sqlalchemy.engine.Engine [generated in 0.00873s] [('Person',), ('Events and Periods',), ('Group',), ('Concept: Cultural and Societal',), ('Geography',), ('Concept: Political and Social',), ('Concept: Economics and Infrastructure',), ('Concept: Terrorism and Security',)  ... displaying 10 of 16 total bound parameter sets ...  ('Education and Institutions',), ('Concept: Legal',)]
# 2024-07-12 15:33:31,941 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-12 15:33:31,947 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-12 15:33:31,950 INFO sqlalchemy.engine.Engine INSERT INTO codes (code_id, term, description, reference, coordinates) VALUES (?, ?, ?, ?, ?)
# 2024-07-12 15:33:31,950 INFO sqlalchemy.engine.Engine [generated in 0.00101s] [(875, 'Zelimkhan Yandarbiyev', 'A Chechen writer and politician who served as President of the Chechen Republic of Ichkeria', 'https://en.wikipedia.org/wiki/Zelimkhan_Yandarbiyev', nan), (338, "Zarqawi's cause", 'Referring to the jihadist campaign led by Abu Musab al-Zarqawi, the leader of al-Qaeda in Iraq during the Iraq War.', 'https://en.wikipedia.org/wiki/Abu_Musab_al-Zarqawi', nan), (837, 'Yugoslavia', 'A historical country in Southeastern and Central Europe for most of the 20th century, until its dissolution in the early 1990s.', 'https://en.wikipedia.org/wiki/Yugoslavia', nan), (618, "YPG (People's Protection Units)", 'A Kurdish militia in Syria that controls a portion of Syrian territory and fought against ISIS.', 'https://en.wikipedia.org/wiki/People%27s_Protection_Units', nan), (434, 'Yemeni Tribalism', "The strong tribal culture within Yemen that significantly influences the country's social and political dynamics.", 'https://en.wikipedia.org/wiki/Yemeni_Crisis_(2011–present)', nan), (444, 'Yemeni Sectarian Landscape', 'The religious and sectarian divisions within Yemen, including various Islamic sects such as Sunnis, Zaidis, and Jarudi Zaidis.', 'https://en.wikipedia.org/wiki/Religion_in_Yemen', nan), (503, 'Yemeni Coast', 'The coastline of Yemen, which is strategically important due to its proximity to key shipping routes and the Bab-el-Mandeb Strait.', 'https://en.wikipedia.org/wiki/Geography_of_Yemen', '14.4990, 46.3666'), (440, 'Yemeni AK-47 Culture', 'The widespread possession and cultural significance of AK-47s among civilians in Yemen.', 'https://en.wikipedia.org/wiki/Yemeni_Crisis_(2011–present)', nan)  ... displaying 10 of 422 total bound parameter sets ...  (913, '2008 Financial Crisis', 'A severe worldwide economic crisis that occurred in the late 2000s, related to the subprime mortgage market and financial instruments like derivatives.', 'https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%932008', nan), (64, '9/11', 'A series of coordinated terrorist attacks by the Islamist terrorist group al-Qaeda against the United States on the morning of Tuesday, September 11, 2001.', 'https://en.wikipedia.org/wiki/September_11_attacks', nan)]
# 2024-07-12 15:33:31,952 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-12 15:33:31,953 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-12 15:33:31,954 INFO sqlalchemy.engine.Engine INSERT INTO episodes (episode_id, episode_title) VALUES (?, ?)
# 2024-07-12 15:33:31,954 INFO sqlalchemy.engine.Engine [generated in 0.00041s] [(1, 'S1E1 - 9/11'), (2, 'S1E2 - War on Terror'), (3, 'S1E3 - Iraq'), (4, 'S1E4 - Yemen'), (5, 'S1E5 - Syria'), (6, 'S1E6 - Returning Jihadists'), (7, 'S2E1 - World War Iran'), (8, 'S2E2 - New World Order')  ... displaying 10 of 51 total bound parameter sets ...  (50, "S4E18: Hezbollah: Israel's Menace or Lebanon's Defender?"), (51, 'S4E19: Yemen: In the Shadow of the Imam')]
# 2024-07-12 15:33:31,956 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-12 15:33:31,970 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-12 15:33:32,016 INFO sqlalchemy.engine.Engine INSERT INTO transcripts (transcript_id, transcript_text, episode_id) VALUES (?, ?, ?)
# 2024-07-12 15:33:32,017 INFO sqlalchemy.engine.Engine [generated in 0.00989s] [(7, "Thomas Small Let's get into it. ", 1), (8, "We'll start this series with an event that catapulted the conflicts of the Middle East into the global consciousness: The Twin Tower attacks on September 11th. ", 1), (9, 'Aimen Dean Okay.', 1), (10, "Thomas Small Right. So, we're just starting. ", 1), (11, 'Aimen Dean Yeah. Go ahead.', 1), (12, "Thomas Small Aimen Dean. How do I introduce Aimen Dean? There is literally no one on Planet Earth like Aimen Dean. Saudi-born, but Bahraini nationali ... (904 characters truncated) ... s his former al-Qaeda – the surviving former al-Qaeda jihadists and their followers want to kill him dead for stabbing them in the back. Aimen Dean. ", 1), (13, 'Aimen Dean Well, that was, you know, a rather ominous introduction. Well, Thomas, how am I going to introduce you? Even after years of knowing you—po ... (715 characters truncated) ... e nuances, the… Understand the Bedouin culture?\' You know, if I want to describe Thomas Small in few words, I would say that he is no small at all. ', 1), (14, "Thomas Small Well, here's the thing, Aimen. I met you and I felt weirdly like I had met some kind of spiritual brother.", 1)  ... displaying 10 of 12401 total bound parameter sets ...  (15609, 'There you will find other fans of the show engaging in heated debates, enlightening conversations, and just generally geeking out over Conflicted related topics.', 51), (15610, 'Conflicted is a Message Heard production. This episode was produced and edited by Harry Stott. Sandra Ferrari is our executive producer. Our theme music is by Matt Huxley and Tom Biddle.', 51)]
# 2024-07-12 15:33:32,034 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-12 15:33:32,041 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-12 15:33:32,051 INFO sqlalchemy.engine.Engine INSERT INTO annotations (annotation_id, transcript_id, code_id) VALUES (?, ?, ?)
# 2024-07-12 15:33:32,051 INFO sqlalchemy.engine.Engine [generated in 0.00466s] [(0, 12, 12), (1, 12, 35), (2, 12, 42), (3, 12, 70), (4, 12, 381), (5, 12, 60), (6, 12, 48), (7, 12, 725)  ... displaying 10 of 5505 total bound parameter sets ...  (5503, 15603, 719), (5504, 15606, 719)]
# 2024-07-12 15:33:32,058 INFO sqlalchemy.engine.Engine COMMIT

# %%
# Step 1: Select a random code item
random_code = session.query(Code).order_by(func.random()).first()

if random_code:
    code_id = random_code.code_id
    print("Random Code ID:")
    print(code_id)
    print("Random Code Item:")
    print(random_code)

    # Step 2: Find all annotations associated with the selected code
    annotations = session.query(Annotation).filter(Annotation.code_id == code_id).all()

    if annotations:
        print('----\nRESULTS\n-----')
        for annotation in annotations:
            print("\nAssociated Annotation:")
            print(annotation)

            # Step 3: Retrieve all transcripts associated with those annotations
            transcript_id = annotation.transcript_id
            transcript = session.query(Transcript).filter(Transcript.transcript_id == transcript_id).first()

            if transcript:
                print("\nAssociated Transcript:")
                print(transcript)
            else:
                print("No associated transcripts found.")
            print("\n")
            print("--------------------------------------------------")
            print("\n")
    else:
        print("No associated annotations found.")
else:
    print("No codes found in the database.")
# Out:
# 2024-07-12 15:33:32,064 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-12 15:33:32,065 INFO sqlalchemy.engine.Engine SELECT codes.code_id AS codes_code_id, codes.term AS codes_term, codes.description AS codes_description, codes.type_id AS codes_type_id, codes.reference AS codes_reference, codes.coordinates AS codes_coordinates
# FROM codes ORDER BY random()
#  LIMIT ? OFFSET ?
# 2024-07-12 15:33:32,066 INFO sqlalchemy.engine.Engine [generated in 0.00031s] (1, 0)
# Random Code ID:
# 319
# Random Code Item:
# Code(code_id=319, term=Ayman al-Zawahiri, description=An Egyptian physician and theologian who became the leader of al-Qaeda after the death of Osama bin Laden., type_id=None, reference=https://en.wikipedia.org/wiki/Ayman_al-Zawahiri, coordinates=None)
# 2024-07-12 15:33:32,067 INFO sqlalchemy.engine.Engine SELECT annotations.annotation_id AS annotations_annotation_id, annotations.transcript_id AS annotations_transcript_id, annotations.code_id AS annotations_code_id
# FROM annotations
# WHERE annotations.code_id = ?
# 2024-07-12 15:33:32,067 INFO sqlalchemy.engine.Engine [generated in 0.00029s] (319,)
# ----
# RESULTS
# -----
#
# Associated Annotation:
# Annotation(annotation_id=398, transcript_id=596, code_id=319)
# 2024-07-12 15:33:32,069 INFO sqlalchemy.engine.Engine SELECT transcripts.transcript_id AS transcripts_transcript_id, transcripts.transcript_text AS transcripts_transcript_text, transcripts.episode_id AS transcripts_episode_id
# FROM transcripts
# WHERE transcripts.transcript_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-12 15:33:32,070 INFO sqlalchemy.engine.Engine [generated in 0.00026s] (596, 1, 0)
#
# Associated Transcript:
# Transcript(transcript_id=596, transcript_text=Thomas Small The War on Terror has been going on for eighteen years, but many people don't know the story well. 9/11 happens. Osama bin Laden, then safe and sound in Afghanistan, being protected by his Taliban allies, is suddenly met with a ferocious onslaught from the United States and its partners in the international coalition, which pounds the Taliban, topples their government in Kabul, and forces. al-Qaeda, Osama bin Laden's deputy, Ayman al-Zawahiri, and everyone else to leave Afghanistan. Some of them stay in AfPak, the mountainous region of the Afghanistan-Pakistan border. , episode_id=2)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=871, transcript_id=1004, code_id=319)
# 2024-07-12 15:33:32,070 INFO sqlalchemy.engine.Engine SELECT transcripts.transcript_id AS transcripts_transcript_id, transcripts.transcript_text AS transcripts_transcript_text, transcripts.episode_id AS transcripts_episode_id
# FROM transcripts
# WHERE transcripts.transcript_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-12 15:33:32,071 INFO sqlalchemy.engine.Engine [cached since 0.001184s ago] (1004, 1, 0)
#
# Associated Transcript:
# Transcript(transcript_id=1004, transcript_text=Thomas Small Anwar Sadat, president of Egypt throughout the '70s, famously signed the Camp David Peace Accords with the Israelis to put an end, or so he hoped, to conflict between Israel and the Arabs, was paid for his pains by being assassinated by jihadists at that time, including Ayman al-Zawahiri, now the leader of al-Qaeda, the grandfather of the sort of total violence we associate now with ISIS. After a time in prison, ended up joining al-Qaeda. And after a series of adventures, establishing what was known as al-Qaeda in Iraq, I remember, in the mid-noughties, he was releasing videos of himself, propaganda videos, brandishing – brandishing knives, brandishing Kalashnikovs, rallying the Muslims to rise up and join him in Iraq to expel the American invader. He was a harbinger for things to come. , episode_id=3)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=1515, transcript_id=2335, code_id=319)
# 2024-07-12 15:33:32,071 INFO sqlalchemy.engine.Engine SELECT transcripts.transcript_id AS transcripts_transcript_id, transcripts.transcript_text AS transcripts_transcript_text, transcripts.episode_id AS transcripts_episode_id
# FROM transcripts
# WHERE transcripts.transcript_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-12 15:33:32,071 INFO sqlalchemy.engine.Engine [cached since 0.001946s ago] (2335, 1, 0)
#
# Associated Transcript:
# Transcript(transcript_id=2335, transcript_text=Aimen Dean Well, shall I tell you about another evil eye doctor. Ayman al-Zawahiri?, episode_id=5)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=3513, transcript_id=10338, code_id=319)
# 2024-07-12 15:33:32,072 INFO sqlalchemy.engine.Engine SELECT transcripts.transcript_id AS transcripts_transcript_id, transcripts.transcript_text AS transcripts_transcript_text, transcripts.episode_id AS transcripts_episode_id
# FROM transcripts
# WHERE transcripts.transcript_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-12 15:33:32,072 INFO sqlalchemy.engine.Engine [cached since 0.002736s ago] (10338, 1, 0)
#
# Associated Transcript:
# Transcript(transcript_id=10338, transcript_text=Thomas:    Yeah. Sayyid Qutb, the great idealog who inspired Osama bin Laden, Ayman al-Zawahiri and all your old friends in Al-Qaeda., episode_id=28)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=3550, transcript_id=10454, code_id=319)
# 2024-07-12 15:33:32,073 INFO sqlalchemy.engine.Engine SELECT transcripts.transcript_id AS transcripts_transcript_id, transcripts.transcript_text AS transcripts_transcript_text, transcripts.episode_id AS transcripts_episode_id
# FROM transcripts
# WHERE transcripts.transcript_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-12 15:33:32,073 INFO sqlalchemy.engine.Engine [cached since 0.003408s ago] (10454, 1, 0)
#
# Associated Transcript:
# Transcript(transcript_id=10454, transcript_text=Thomas:    So, Aimen, as you say, Iran-Iraq War today, but before we get started on that topic, I want to talk about the flying blender that vaporized your old buddy Ayman al-Zawahiri the other day., episode_id=29)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=3552, transcript_id=10455, code_id=319)
# 2024-07-12 15:33:32,073 INFO sqlalchemy.engine.Engine SELECT transcripts.transcript_id AS transcripts_transcript_id, transcripts.transcript_text AS transcripts_transcript_text, transcripts.episode_id AS transcripts_episode_id
# FROM transcripts
# WHERE transcripts.transcript_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-12 15:33:32,073 INFO sqlalchemy.engine.Engine [cached since 0.004062s ago] (10455, 1, 0)
#
# Associated Transcript:
# Transcript(transcript_id=10455, transcript_text=On the 31st of July to be specific, Ayman al-Zawahiri was vaporized in a drone strike as he stepped out onto the balcony of his house. I mean, his family weren’t harmed, just he. He was vaporized by a blender, a hellfire missile that's been sort of reconfigured to, without a warhead just with blades. Is this true?, episode_id=29)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=3553, transcript_id=10459, code_id=319)
# 2024-07-12 15:33:32,074 INFO sqlalchemy.engine.Engine SELECT transcripts.transcript_id AS transcripts_transcript_id, transcripts.transcript_text AS transcripts_transcript_text, transcripts.episode_id AS transcripts_episode_id
# FROM transcripts
# WHERE transcripts.transcript_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-12 15:33:32,074 INFO sqlalchemy.engine.Engine [cached since 0.004706s ago] (10459, 1, 0)
#
# Associated Transcript:
# Transcript(transcript_id=10459, transcript_text=Thomas:    I mean, it's hard to feel sorry for Ayman al-Zawahiri and we'll talk more about him in our next episode, which is about the Soviet invasion of Afghanistan., episode_id=29)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=3555, transcript_id=10461, code_id=319)
# 2024-07-12 15:33:32,075 INFO sqlalchemy.engine.Engine SELECT transcripts.transcript_id AS transcripts_transcript_id, transcripts.transcript_text AS transcripts_transcript_text, transcripts.episode_id AS transcripts_episode_id
# FROM transcripts
# WHERE transcripts.transcript_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-12 15:33:32,075 INFO sqlalchemy.engine.Engine [cached since 0.005313s ago] (10461, 1, 0)
#
# Associated Transcript:
# Transcript(transcript_id=10461, transcript_text=Thomas:    So, Ayman al-Zawahiri will be there, but it's hard to feel sorry for a guy like that, but I mean, what a way to go. It's not the noblest end., episode_id=29)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=3559, transcript_id=10465, code_id=319)
# 2024-07-12 15:33:32,075 INFO sqlalchemy.engine.Engine SELECT transcripts.transcript_id AS transcripts_transcript_id, transcripts.transcript_text AS transcripts_transcript_text, transcripts.episode_id AS transcripts_episode_id
# FROM transcripts
# WHERE transcripts.transcript_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-12 15:33:32,075 INFO sqlalchemy.engine.Engine [cached since 0.005942s ago] (10465, 1, 0)
#
# Associated Transcript:
# Transcript(transcript_id=10465, transcript_text=Thomas:    As ever, we have amazing timing here on Conflicted. We're about to talk about Afghanistan. Next time, here Conflicted is coming full circle. Ayman al-Zawahiri is one of the masterminds of 9/11 vaporized by a blade., episode_id=29)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=3698, transcript_id=10734, code_id=319)
# 2024-07-12 15:33:32,076 INFO sqlalchemy.engine.Engine SELECT transcripts.transcript_id AS transcripts_transcript_id, transcripts.transcript_text AS transcripts_transcript_text, transcripts.episode_id AS transcripts_episode_id
# FROM transcripts
# WHERE transcripts.transcript_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-12 15:33:32,076 INFO sqlalchemy.engine.Engine [cached since 0.006592s ago] (10734, 1, 0)
#
# Associated Transcript:
# Transcript(transcript_id=10734, transcript_text=So, he decided to found Al-Qaeda, blah, blah, blah, blah, blah. And it all ends up with Ayman al-Zawahiri on a balcony in Kabul being shredded by a flying blender., episode_id=29)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=3712, transcript_id=10767, code_id=319)
# 2024-07-12 15:33:32,076 INFO sqlalchemy.engine.Engine SELECT transcripts.transcript_id AS transcripts_transcript_id, transcripts.transcript_text AS transcripts_transcript_text, transcripts.episode_id AS transcripts_episode_id
# FROM transcripts
# WHERE transcripts.transcript_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-12 15:33:32,077 INFO sqlalchemy.engine.Engine [cached since 0.007219s ago] (10767, 1, 0)
#
# Associated Transcript:
# Transcript(transcript_id=10767, transcript_text=It wasn't just Salman Rushdie's assassination attempt, Aimen, that keeps Conflicted in sync with the headlines. As we talked about last time, Ayman al-Zawahiri now, the former leader of al-Qaeda was assassinated two weeks ago by a U.S. drone in Afghanistan., episode_id=30)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=3717, transcript_id=10769, code_id=319)
# 2024-07-12 15:33:32,077 INFO sqlalchemy.engine.Engine SELECT transcripts.transcript_id AS transcripts_transcript_id, transcripts.transcript_text AS transcripts_transcript_text, transcripts.episode_id AS transcripts_episode_id
# FROM transcripts
# WHERE transcripts.transcript_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-12 15:33:32,077 INFO sqlalchemy.engine.Engine [cached since 0.00782s ago] (10769, 1, 0)
#
# Associated Transcript:
# Transcript(transcript_id=10769, transcript_text=So, Afghanistan remains at the top of the headlines, but the main point is, is that these two characters, Ayman al-Zawahiri, and Anas Haqqani, or at least Anas Haqqani’s father will be players in today's episode of Conflicted, which is all about the anti-Soviet Jihad of the late seventies and of the 1980s. The Soviet-Afghan War., episode_id=30)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=3941, transcript_id=11035, code_id=319)
# 2024-07-12 15:33:32,078 INFO sqlalchemy.engine.Engine SELECT transcripts.transcript_id AS transcripts_transcript_id, transcripts.transcript_text AS transcripts_transcript_text, transcripts.episode_id AS transcripts_episode_id
# FROM transcripts
# WHERE transcripts.transcript_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-12 15:33:32,078 INFO sqlalchemy.engine.Engine [cached since 0.008337s ago] (11035, 1, 0)
#
# Associated Transcript:
# Transcript(transcript_id=11035, transcript_text=Thomas:    Yes, Abdullah Azzam, we're back. Remember dear listener, we left him in 1979 in Amman, Jordan, with his mouth wide open as the Soviets invaded Afghanistan. And now, we're back to Abdullah Azzam and we will tell the rest of the story of the anti-Soviet jihad through his eyes, really, although many players will also come up; bin Laden, Ayman al-Zawahiri, and others., episode_id=30)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=3968, transcript_id=11070, code_id=319)
# 2024-07-12 15:33:32,078 INFO sqlalchemy.engine.Engine SELECT transcripts.transcript_id AS transcripts_transcript_id, transcripts.transcript_text AS transcripts_transcript_text, transcripts.episode_id AS transcripts_episode_id
# FROM transcripts
# WHERE transcripts.transcript_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-12 15:33:32,078 INFO sqlalchemy.engine.Engine [cached since 0.008954s ago] (11070, 1, 0)
#
# Associated Transcript:
# Transcript(transcript_id=11070, transcript_text=Ayman al-Zawahiri, for example, who would go on to lead Al-Qaeda after bin Laden's death, he came to Afghanistan as early as 1980, initially as a doctor helping in a hospital charity though he was an Islamic radical., episode_id=30)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=4011, transcript_id=11115, code_id=319)
# 2024-07-12 15:33:32,079 INFO sqlalchemy.engine.Engine SELECT transcripts.transcript_id AS transcripts_transcript_id, transcripts.transcript_text AS transcripts_transcript_text, transcripts.episode_id AS transcripts_episode_id
# FROM transcripts
# WHERE transcripts.transcript_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-12 15:33:32,079 INFO sqlalchemy.engine.Engine [cached since 0.009701s ago] (11115, 1, 0)
#
# Associated Transcript:
# Transcript(transcript_id=11115, transcript_text=They included Abu Ubaidah al-Banshiri, Abu Hafs al-Masri, Ayman al-Zawahiri, these three are Egyptians from the Islamic Egyptian jihad., episode_id=30)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=4569, transcript_id=13184, code_id=319)
# 2024-07-12 15:33:32,080 INFO sqlalchemy.engine.Engine SELECT transcripts.transcript_id AS transcripts_transcript_id, transcripts.transcript_text AS transcripts_transcript_text, transcripts.episode_id AS transcripts_episode_id
# FROM transcripts
# WHERE transcripts.transcript_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-12 15:33:32,080 INFO sqlalchemy.engine.Engine [cached since 0.01034s ago] (13184, 1, 0)
#
# Associated Transcript:
# Transcript(transcript_id=13184, transcript_text=Thomas: In the runup to 9/11, in Al-Qaeda, there's something like a dynamic between Ibn ʿAbd al-Wahhab and Muhammad bin Saud, in the dynamic between Osama Bin Laden and Ayman al-Zawahiri and those Egyptians., episode_id=40)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=5102, transcript_id=14538, code_id=319)
# 2024-07-12 15:33:32,080 INFO sqlalchemy.engine.Engine SELECT transcripts.transcript_id AS transcripts_transcript_id, transcripts.transcript_text AS transcripts_transcript_text, transcripts.episode_id AS transcripts_episode_id
# FROM transcripts
# WHERE transcripts.transcript_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-12 15:33:32,080 INFO sqlalchemy.engine.Engine [cached since 0.01097s ago] (14538, 1, 0)
#
# Associated Transcript:
# Transcript(transcript_id=14538, transcript_text=And I remember I was there at dinner and people gathered, this big place where we always gather for the supper before we go to sleep and present there was Ayman al-Zawahiri and Abu Musab al-Suri. Abu Musab al-Suri for some of the dear listeners who don't know who he is, he was one of the most brilliant strategic minds that the jihadist movement ever produced., episode_id=47)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=5103, transcript_id=14539, code_id=319)
# 2024-07-12 15:33:32,081 INFO sqlalchemy.engine.Engine SELECT transcripts.transcript_id AS transcripts_transcript_id, transcripts.transcript_text AS transcripts_transcript_text, transcripts.episode_id AS transcripts_episode_id
# FROM transcripts
# WHERE transcripts.transcript_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-12 15:33:32,081 INFO sqlalchemy.engine.Engine [cached since 0.01166s ago] (14539, 1, 0)
#
# Associated Transcript:
# Transcript(transcript_id=14539, transcript_text=An interesting point were raised during the discussions between Ayman al-Zawahiri and Abu Musab al-Suri over that dinner that night., episode_id=47)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=5123, transcript_id=14568, code_id=319)
# 2024-07-12 15:33:32,081 INFO sqlalchemy.engine.Engine SELECT transcripts.transcript_id AS transcripts_transcript_id, transcripts.transcript_text AS transcripts_transcript_text, transcripts.episode_id AS transcripts_episode_id
# FROM transcripts
# WHERE transcripts.transcript_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-12 15:33:32,082 INFO sqlalchemy.engine.Engine [cached since 0.01215s ago] (14568, 1, 0)
#
# Associated Transcript:
# Transcript(transcript_id=14568, transcript_text=Aimen: Well, because that's exactly what both Ayman al-Zawahiri and Abu Musab al-Suri, two of the grand titans of the jihadist movement in the 20 and 21st centuries, I mean stated that they were successful based on the ideas of the Muslim Brotherhood and Sayyid Qutb., episode_id=47)
#
#
# --------------------------------------------------
