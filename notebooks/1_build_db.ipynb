# %% [markdown]
# # Import data from Conflicted Glossary

# %%
import pandas as pd

# Load the CSV files into DataFrames
codes_df = pd.read_csv('../_temp/glossary.csv')  # type: ignore
transcripts_df = pd.read_csv('../_temp/transcripts.csv')  # type: ignore

# Rename columns according to the provided mapping
codes_df = codes_df.rename(columns={
    'Glossary ID': 'code_id',
    'Term': 'term',
    'Description': 'description',
    'Type': 'type',
    'Read more': 'reference',
    'Lat/Long': 'coordinates'
})
codes_df = codes_df[['code_id', 'term', 'description', 'type', 'reference', 'coordinates']]

transcripts_df = transcripts_df.rename(columns={
    'Text ID': 'transcript_id',
    'Text': 'transcript_text',
    'Episode ID': 'episode_id',
    'Episode': 'episode_title',
    'Glossary IDs': 'code_ids'
})
# drop the columns that are not transcript_id, transcript_text, episode_id, episode_title, code_ids
transcripts_df = transcripts_df[['transcript_id', 'transcript_text', 'episode_id', 'episode_title', 'code_ids']]

transcripts_df['code_ids'] = transcripts_df['code_ids'].fillna('') # type: ignore

# create a dataframe with all unique episode_id and episode_title
episode_df = transcripts_df[['episode_id', 'episode_title']].drop_duplicates()

# create a dataframe with all unique glossary type
code_type_df = codes_df[['type']].drop_duplicates()
# rename the column to type_name
code_type_df = code_type_df.rename(columns={'type': 'type_name'})

# %%
# Create a new DataFrame annotations_df with columns transcript_id, code_id
annotations_df = pd.DataFrame(columns=['transcript_id', 'code_id'])

# Iterate over each row in transcripts_df and add rows to annotations_df
rows_to_add = []
for index, row in transcripts_df.iterrows():
    transcript_id = row['transcript_id']
    code_ids = row['code_ids'].split(';')
    for code_id in code_ids if code_ids != [''] else []:
        code_id = int(code_id)
        rows_to_add.append({'transcript_id': transcript_id, 'code_id': code_id})

transcripts_df.drop(columns=['code_ids'], inplace=True) # type: ignore

# Convert list of rows to DataFrame and concatenate
annotations_df = pd.concat([annotations_df, pd.DataFrame(rows_to_add)], ignore_index=True)

# Convert code_id to int
annotations_df['code_id'] = annotations_df['code_id'].astype(int)

# Add a column annotation_id to annotations_df
annotations_df['annotation_id'] = annotations_df.index

# %% [markdown]
# # Define Database

# %%
from kanot.db.schema import create_database, CodeType, Code, Episode, Transcript, Annotation
from sqlalchemy import create_engine, Engine
from sqlalchemy.orm import sessionmaker

# Create a connection to the SQLite database
engine: Engine = create_engine('sqlite:///conflicted_glossary.db', echo=True)
MySession = sessionmaker(bind=engine)
session = MySession()

# Create the tables in the database
create_database(engine)
# Out:
# 2024-07-11 11:17:58,124 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-11 11:17:58,125 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("code_types")
# 2024-07-11 11:17:58,125 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-11 11:17:58,125 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("codes")
# 2024-07-11 11:17:58,126 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-11 11:17:58,126 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("episodes")
# 2024-07-11 11:17:58,126 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-11 11:17:58,126 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("transcripts")
# 2024-07-11 11:17:58,127 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-11 11:17:58,127 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("annotations")
# 2024-07-11 11:17:58,127 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-11 11:17:58,128 INFO sqlalchemy.engine.Engine COMMIT

# %%
from sqlalchemy import func
from sqlalchemy.orm import Session
from sqlalchemy.ext.declarative import DeclarativeMeta
from sqlalchemy.exc import IntegrityError
from typing import Any, Hashable

# Define a function to insert data from a DataFrame
def insert_data(df: pd.DataFrame, model: DeclarativeMeta, session: Session) -> None:
    data: list[dict[Hashable, Any]] = df.to_dict(orient='records') # type: ignore
    
    try:
        session.bulk_insert_mappings(model, data) # type: ignore
        session.commit()
    except IntegrityError as e:
        print(f"Unique constraint violation: {e}")
        session.rollback()

# Insert data into the code_types table
insert_data(code_type_df, CodeType, session)

# Insert data into the codes table
insert_data(codes_df, Code, session)

# Insert data into the episodes table
insert_data(episode_df, Episode, session)

# Insert data into the transcripts table
insert_data(transcripts_df, Transcript, session)

# Insert data into the annotations table
insert_data(annotations_df, Annotation, session)

# Close the session
session.close()
# Out:
# 2024-07-11 11:17:58,140 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-11 11:17:58,141 INFO sqlalchemy.engine.Engine INSERT INTO code_types (type_id) VALUES (NULL)
# 2024-07-11 11:17:58,141 INFO sqlalchemy.engine.Engine [generated in 0.00041s] [(), (), (), (), (), (), (), ()  ... displaying 10 of 16 total bound parameter sets ...  (), ()]
# 2024-07-11 11:17:58,142 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-11 11:17:58,144 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-11 11:17:58,146 INFO sqlalchemy.engine.Engine INSERT INTO codes (code_id, term, description, reference, coordinates) VALUES (?, ?, ?, ?, ?)
# 2024-07-11 11:17:58,146 INFO sqlalchemy.engine.Engine [generated in 0.00089s] [(875, 'Zelimkhan Yandarbiyev', 'A Chechen writer and politician who served as President of the Chechen Republic of Ichkeria', 'https://en.wikipedia.org/wiki/Zelimkhan_Yandarbiyev', nan), (338, "Zarqawi's cause", 'Referring to the jihadist campaign led by Abu Musab al-Zarqawi, the leader of al-Qaeda in Iraq during the Iraq War.', 'https://en.wikipedia.org/wiki/Abu_Musab_al-Zarqawi', nan), (837, 'Yugoslavia', 'A historical country in Southeastern and Central Europe for most of the 20th century, until its dissolution in the early 1990s.', 'https://en.wikipedia.org/wiki/Yugoslavia', nan), (618, "YPG (People's Protection Units)", 'A Kurdish militia in Syria that controls a portion of Syrian territory and fought against ISIS.', 'https://en.wikipedia.org/wiki/People%27s_Protection_Units', nan), (434, 'Yemeni Tribalism', "The strong tribal culture within Yemen that significantly influences the country's social and political dynamics.", 'https://en.wikipedia.org/wiki/Yemeni_Crisis_(2011–present)', nan), (444, 'Yemeni Sectarian Landscape', 'The religious and sectarian divisions within Yemen, including various Islamic sects such as Sunnis, Zaidis, and Jarudi Zaidis.', 'https://en.wikipedia.org/wiki/Religion_in_Yemen', nan), (503, 'Yemeni Coast', 'The coastline of Yemen, which is strategically important due to its proximity to key shipping routes and the Bab-el-Mandeb Strait.', 'https://en.wikipedia.org/wiki/Geography_of_Yemen', '14.4990, 46.3666'), (440, 'Yemeni AK-47 Culture', 'The widespread possession and cultural significance of AK-47s among civilians in Yemen.', 'https://en.wikipedia.org/wiki/Yemeni_Crisis_(2011–present)', nan)  ... displaying 10 of 422 total bound parameter sets ...  (913, '2008 Financial Crisis', 'A severe worldwide economic crisis that occurred in the late 2000s, related to the subprime mortgage market and financial instruments like derivatives.', 'https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%932008', nan), (64, '9/11', 'A series of coordinated terrorist attacks by the Islamist terrorist group al-Qaeda against the United States on the morning of Tuesday, September 11, 2001.', 'https://en.wikipedia.org/wiki/September_11_attacks', nan)]
# 2024-07-11 11:17:58,147 INFO sqlalchemy.engine.Engine ROLLBACK
# Unique constraint violation: (sqlite3.IntegrityError) UNIQUE constraint failed: codes.code_id
# [SQL: INSERT INTO codes (code_id, term, description, reference, coordinates) VALUES (?, ?, ?, ?, ?)]
# [parameters: [(875, 'Zelimkhan Yandarbiyev', 'A Chechen writer and politician who served as President of the Chechen Republic of Ichkeria', 'https://en.wikipedia.org/wiki/Zelimkhan_Yandarbiyev', nan), (338, "Zarqawi's cause", 'Referring to the jihadist campaign led by Abu Musab al-Zarqawi, the leader of al-Qaeda in Iraq during the Iraq War.', 'https://en.wikipedia.org/wiki/Abu_Musab_al-Zarqawi', nan), (837, 'Yugoslavia', 'A historical country in Southeastern and Central Europe for most of the 20th century, until its dissolution in the early 1990s.', 'https://en.wikipedia.org/wiki/Yugoslavia', nan), (618, "YPG (People's Protection Units)", 'A Kurdish militia in Syria that controls a portion of Syrian territory and fought against ISIS.', 'https://en.wikipedia.org/wiki/People%27s_Protection_Units', nan), (434, 'Yemeni Tribalism', "The strong tribal culture within Yemen that significantly influences the country's social and political dynamics.", 'https://en.wikipedia.org/wiki/Yemeni_Crisis_(2011–present)', nan), (444, 'Yemeni Sectarian Landscape', 'The religious and sectarian divisions within Yemen, including various Islamic sects such as Sunnis, Zaidis, and Jarudi Zaidis.', 'https://en.wikipedia.org/wiki/Religion_in_Yemen', nan), (503, 'Yemeni Coast', 'The coastline of Yemen, which is strategically important due to its proximity to key shipping routes and the Bab-el-Mandeb Strait.', 'https://en.wikipedia.org/wiki/Geography_of_Yemen', '14.4990, 46.3666'), (440, 'Yemeni AK-47 Culture', 'The widespread possession and cultural significance of AK-47s among civilians in Yemen.', 'https://en.wikipedia.org/wiki/Yemeni_Crisis_(2011–present)', nan)  ... displaying 10 of 422 total bound parameter sets ...  (913, '2008 Financial Crisis', 'A severe worldwide economic crisis that occurred in the late 2000s, related to the subprime mortgage market and financial instruments like derivatives.', 'https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%932008', nan), (64, '9/11', 'A series of coordinated terrorist attacks by the Islamist terrorist group al-Qaeda against the United States on the morning of Tuesday, September 11, 2001.', 'https://en.wikipedia.org/wiki/September_11_attacks', nan)]]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# 2024-07-11 11:17:58,149 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-11 11:17:58,150 INFO sqlalchemy.engine.Engine INSERT INTO episodes (episode_id, episode_title) VALUES (?, ?)
# 2024-07-11 11:17:58,150 INFO sqlalchemy.engine.Engine [generated in 0.00041s] [(1, 'S1E1 - 9/11'), (2, 'S1E2 - War on Terror'), (3, 'S1E3 - Iraq'), (4, 'S1E4 - Yemen'), (5, 'S1E5 - Syria'), (6, 'S1E6 - Returning Jihadists'), (7, 'S2E1 - World War Iran'), (8, 'S2E2 - New World Order')  ... displaying 10 of 51 total bound parameter sets ...  (50, "S4E18: Hezbollah: Israel's Menace or Lebanon's Defender?"), (51, 'S4E19: Yemen: In the Shadow of the Imam')]
# 2024-07-11 11:17:58,150 INFO sqlalchemy.engine.Engine ROLLBACK
# Unique constraint violation: (sqlite3.IntegrityError) UNIQUE constraint failed: episodes.episode_title
# [SQL: INSERT INTO episodes (episode_id, episode_title) VALUES (?, ?)]
# [parameters: [(1, 'S1E1 - 9/11'), (2, 'S1E2 - War on Terror'), (3, 'S1E3 - Iraq'), (4, 'S1E4 - Yemen'), (5, 'S1E5 - Syria'), (6, 'S1E6 - Returning Jihadists'), (7, 'S2E1 - World War Iran'), (8, 'S2E2 - New World Order')  ... displaying 10 of 51 total bound parameter sets ...  (50, "S4E18: Hezbollah: Israel's Menace or Lebanon's Defender?"), (51, 'S4E19: Yemen: In the Shadow of the Imam')]]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# 2024-07-11 11:17:58,185 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-11 11:17:58,240 INFO sqlalchemy.engine.Engine INSERT INTO transcripts (transcript_id, transcript_text, episode_id) VALUES (?, ?, ?)
# 2024-07-11 11:17:58,241 INFO sqlalchemy.engine.Engine [generated in 0.01188s] [(7, "Thomas Small Let's get into it. ", 1), (8, "We'll start this series with an event that catapulted the conflicts of the Middle East into the global consciousness: The Twin Tower attacks on September 11th. ", 1), (9, 'Aimen Dean Okay.', 1), (10, "Thomas Small Right. So, we're just starting. ", 1), (11, 'Aimen Dean Yeah. Go ahead.', 1), (12, "Thomas Small Aimen Dean. How do I introduce Aimen Dean? There is literally no one on Planet Earth like Aimen Dean. Saudi-born, but Bahraini nationali ... (904 characters truncated) ... s his former al-Qaeda – the surviving former al-Qaeda jihadists and their followers want to kill him dead for stabbing them in the back. Aimen Dean. ", 1), (13, 'Aimen Dean Well, that was, you know, a rather ominous introduction. Well, Thomas, how am I going to introduce you? Even after years of knowing you—po ... (715 characters truncated) ... e nuances, the… Understand the Bedouin culture?\' You know, if I want to describe Thomas Small in few words, I would say that he is no small at all. ', 1), (14, "Thomas Small Well, here's the thing, Aimen. I met you and I felt weirdly like I had met some kind of spiritual brother.", 1)  ... displaying 10 of 12401 total bound parameter sets ...  (15609, 'There you will find other fans of the show engaging in heated debates, enlightening conversations, and just generally geeking out over Conflicted related topics.', 51), (15610, 'Conflicted is a Message Heard production. This episode was produced and edited by Harry Stott. Sandra Ferrari is our executive producer. Our theme music is by Matt Huxley and Tom Biddle.', 51)]
# 2024-07-11 11:17:58,241 INFO sqlalchemy.engine.Engine ROLLBACK
# Unique constraint violation: (sqlite3.IntegrityError) UNIQUE constraint failed: transcripts.transcript_id
# [SQL: INSERT INTO transcripts (transcript_id, transcript_text, episode_id) VALUES (?, ?, ?)]
# [parameters: [(7, "Thomas Small Let's get into it. ", 1), (8, "We'll start this series with an event that catapulted the conflicts of the Middle East into the global consciousness: The Twin Tower attacks on September 11th. ", 1), (9, 'Aimen Dean Okay.', 1), (10, "Thomas Small Right. So, we're just starting. ", 1), (11, 'Aimen Dean Yeah. Go ahead.', 1), (12, "Thomas Small Aimen Dean. How do I introduce Aimen Dean? There is literally no one on Planet Earth like Aimen Dean. Saudi-born, but Bahraini nationali ... (904 characters truncated) ... s his former al-Qaeda – the surviving former al-Qaeda jihadists and their followers want to kill him dead for stabbing them in the back. Aimen Dean. ", 1), (13, 'Aimen Dean Well, that was, you know, a rather ominous introduction. Well, Thomas, how am I going to introduce you? Even after years of knowing you—po ... (715 characters truncated) ... e nuances, the… Understand the Bedouin culture?\' You know, if I want to describe Thomas Small in few words, I would say that he is no small at all. ', 1), (14, "Thomas Small Well, here's the thing, Aimen. I met you and I felt weirdly like I had met some kind of spiritual brother.", 1)  ... displaying 10 of 12401 total bound parameter sets ...  (15609, 'There you will find other fans of the show engaging in heated debates, enlightening conversations, and just generally geeking out over Conflicted related topics.', 51), (15610, 'Conflicted is a Message Heard production. This episode was produced and edited by Harry Stott. Sandra Ferrari is our executive producer. Our theme music is by Matt Huxley and Tom Biddle.', 51)]]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# 2024-07-11 11:17:58,246 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-11 11:17:58,258 INFO sqlalchemy.engine.Engine INSERT INTO annotations (annotation_id, transcript_id, code_id) VALUES (?, ?, ?)
# 2024-07-11 11:17:58,259 INFO sqlalchemy.engine.Engine [generated in 0.00540s] [(0, 12, 12), (1, 12, 35), (2, 12, 42), (3, 12, 70), (4, 12, 381), (5, 12, 60), (6, 12, 48), (7, 12, 725)  ... displaying 10 of 5505 total bound parameter sets ...  (5503, 15603, 719), (5504, 15606, 719)]
# 2024-07-11 11:17:58,259 INFO sqlalchemy.engine.Engine ROLLBACK
# Unique constraint violation: (sqlite3.IntegrityError) UNIQUE constraint failed: annotations.annotation_id
# [SQL: INSERT INTO annotations (annotation_id, transcript_id, code_id) VALUES (?, ?, ?)]
# [parameters: [(0, 12, 12), (1, 12, 35), (2, 12, 42), (3, 12, 70), (4, 12, 381), (5, 12, 60), (6, 12, 48), (7, 12, 725)  ... displaying 10 of 5505 total bound parameter sets ...  (5503, 15603, 719), (5504, 15606, 719)]]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
# Step 1: Select a random code item
random_code = session.query(Code).order_by(func.random()).first()

if random_code:
    code_id = random_code.code_id
    print("Random Code ID:")
    print(code_id)
    print("Random Code Item:")
    print(random_code)

    # Step 2: Find all annotations associated with the selected code
    annotations = session.query(Annotation).filter(Annotation.code_id == code_id).all()

    if annotations:
        print('----\nRESULTS\n-----')
        for annotation in annotations:
            print("\nAssociated Annotation:")
            print(annotation)

            # Step 3: Retrieve all transcripts associated with those annotations
            transcript_id = annotation.transcript_id
            transcript = session.query(Transcript).filter(Transcript.transcript_id == transcript_id).first()

            if transcript:
                print("\nAssociated Transcript:")
                print(transcript)
            else:
                print("No associated transcripts found.")
            print("\n")
            print("--------------------------------------------------")
            print("\n")
    else:
        print("No associated annotations found.")
else:
    print("No codes found in the database.")
# Out:
# 2024-07-11 11:17:58,265 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-11 11:17:58,267 INFO sqlalchemy.engine.Engine SELECT codes.code_id AS codes_code_id, codes.term AS codes_term, codes.description AS codes_description, codes.type_id AS codes_type_id, codes.reference AS codes_reference, codes.coordinates AS codes_coordinates
# FROM codes ORDER BY random()
#  LIMIT ? OFFSET ?
# 2024-07-11 11:17:58,267 INFO sqlalchemy.engine.Engine [generated in 0.00054s] (1, 0)
# Random Code ID:
# 469
# Random Code Item:
# Code(code_id=469, term=Scud Missiles, description=A series of tactical ballistic missiles developed by the Soviet Union during the Cold War., type_id=None, reference=https://en.wikipedia.org/wiki/Scud, coordinates=None)
# 2024-07-11 11:17:58,269 INFO sqlalchemy.engine.Engine SELECT annotations.annotation_id AS annotations_annotation_id, annotations.transcript_id AS annotations_transcript_id, annotations.code_id AS annotations_code_id
# FROM annotations
# WHERE annotations.code_id = ?
# 2024-07-11 11:17:58,270 INFO sqlalchemy.engine.Engine [generated in 0.00039s] (469,)
# ----
# RESULTS
# -----
#
# Associated Annotation:
# Annotation(annotation_id=1340, transcript_id=1377, code_id=469)
# 2024-07-11 11:17:58,273 INFO sqlalchemy.engine.Engine SELECT transcripts.transcript_id AS transcripts_transcript_id, transcripts.transcript_text AS transcripts_transcript_text, transcripts.episode_id AS transcripts_episode_id
# FROM transcripts
# WHERE transcripts.transcript_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-11 11:17:58,273 INFO sqlalchemy.engine.Engine [generated in 0.00034s] (1377, 1, 0)
#
# Associated Transcript:
# Transcript(transcript_id=1377, transcript_text=Thomas Small Ali – Ali Abdullah Saleh had built up an arsenal of six hundred Scud missiles. , episode_id=4)
#
#
# --------------------------------------------------
