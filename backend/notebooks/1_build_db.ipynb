# %% [markdown]
# # Import data from Conflicted Glossary

# %%
import pandas as pd

# Load the CSV files into DataFrames
codes_df = pd.read_csv('../_temp/glossary.csv')  # type: ignore
elements_df = pd.read_csv('../_temp/transcripts.csv')  # type: ignore

# Rename columns according to the provided mapping
codes_df = codes_df.rename(columns={
    'Glossary ID': 'code_id',
    'Term': 'term',
    'Description': 'description',
    'Type': 'type',
    'Read more': 'reference',
    'Lat/Long': 'coordinates'
})

elements_df = elements_df.rename(columns={
    'Text ID': 'element_id',
    'Text': 'element_text',
    'Episode ID': 'segment_id',
    'Episode': 'segment_title',
    'Glossary IDs': 'code_ids'
})
# drop the columns that are not element_id, element_text, segment_id, segment_title, code_ids
elements_df = elements_df[['element_id', 'element_text', 'segment_id', 'segment_title', 'code_ids']]

elements_df['code_ids'] = elements_df['code_ids'].fillna('') # type: ignore

# remove any rows in the elements_df where the element_text is empty
elements_df = elements_df[elements_df['element_text'].notnull()]

# create a dataframe with all unique segment_id and segment_title
segment_df = elements_df[['segment_id', 'segment_title']].drop_duplicates()

# create a dataframe series_df with autoincrementing column series_id and series_title and add one row with series_title = 'Conflicted Podcast'
series_df = pd.DataFrame({'series_id': [1], 'series_title': ['Conflicted Podcast']})

# add a column series_id to the segment_df dataframe and set the value to 1 for all rows
segment_df['series_id'] = 1

# create a dataframe with all unique glossary type
code_type_df = codes_df[['type']].drop_duplicates()
# rename the column to type_name
code_type_df = code_type_df.rename(columns={'type': 'type_name'})
# create an incrementing type_id column
code_type_df['type_id'] = range(1, len(code_type_df) + 1)

# Create a column type_id in the codes_df dataframe and map the type_name to the type_id
# Merge the code_type_df with the codes_df on type = type_name
codes_df = codes_df.merge(code_type_df, left_on='type', right_on='type_name', how='left') # type: ignore
codes_df = codes_df.rename(columns={'type_name': 'type_id'})
codes_df = codes_df[['code_id', 'term', 'description', 'type_id', 'reference', 'coordinates']]

# %%
# Create a new DataFrame annotations_df with columns element_id, code_id
annotations_df = pd.DataFrame(columns=['element_id', 'code_id'])

# Iterate over each row in elements_df and add rows to annotations_df
rows_to_add = []
for index, row in elements_df.iterrows():
    element_id = row['element_id']
    code_ids = row['code_ids'].split(';')
    for code_id in code_ids if code_ids != [''] else []:
        code_id = int(code_id)
        rows_to_add.append({'element_id': element_id, 'code_id': code_id})

elements_df.drop(columns=['code_ids', 'segment_title'], inplace=True) # type: ignore

# Convert list of rows to DataFrame and concatenate
annotations_df = pd.concat([annotations_df, pd.DataFrame(rows_to_add)], ignore_index=True)

# Convert code_id to int
annotations_df['code_id'] = annotations_df['code_id'].astype(int)

# Add a column annotation_id to annotations_df
annotations_df['annotation_id'] = annotations_df.index

# %% [markdown]
# # Define Database

# %%
from kanot.db.schema import create_database, drop_database, CodeType, Code, Series, Segment, Element, Annotation
from sqlalchemy import create_engine, Engine
from sqlalchemy.orm import sessionmaker

# Create a connection to the SQLite database
engine: Engine = create_engine('sqlite:///../local_database.db', echo=True)
MySession = sessionmaker(bind=engine)
session = MySession()

drop = True
if drop:
    # Drop all the tables in the database
    drop_database(engine)

# Create the tables in the database
create_database(engine)
# Out:
# 2024-07-20 00:22:58,084 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-20 00:22:58,084 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("code_types")
# 2024-07-20 00:22:58,084 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-20 00:22:58,085 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("codes")
# 2024-07-20 00:22:58,085 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-20 00:22:58,085 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("series")
# 2024-07-20 00:22:58,086 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-20 00:22:58,086 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("segments")
# 2024-07-20 00:22:58,086 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-20 00:22:58,086 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("elements")
# 2024-07-20 00:22:58,086 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-20 00:22:58,087 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("annotations")
# 2024-07-20 00:22:58,087 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-20 00:22:58,087 INFO sqlalchemy.engine.Engine
# DROP TABLE annotations
# 2024-07-20 00:22:58,087 INFO sqlalchemy.engine.Engine [no key 0.00019s] ()
# 2024-07-20 00:22:58,089 INFO sqlalchemy.engine.Engine
# DROP TABLE elements
# 2024-07-20 00:22:58,089 INFO sqlalchemy.engine.Engine [no key 0.00015s] ()
# 2024-07-20 00:22:58,091 INFO sqlalchemy.engine.Engine
# DROP TABLE segments
# 2024-07-20 00:22:58,091 INFO sqlalchemy.engine.Engine [no key 0.00022s] ()
# 2024-07-20 00:22:58,092 INFO sqlalchemy.engine.Engine
# DROP TABLE codes
# 2024-07-20 00:22:58,092 INFO sqlalchemy.engine.Engine [no key 0.00015s] ()
# 2024-07-20 00:22:58,093 INFO sqlalchemy.engine.Engine
# DROP TABLE series
# 2024-07-20 00:22:58,093 INFO sqlalchemy.engine.Engine [no key 0.00012s] ()
# 2024-07-20 00:22:58,094 INFO sqlalchemy.engine.Engine
# DROP TABLE code_types
# 2024-07-20 00:22:58,094 INFO sqlalchemy.engine.Engine [no key 0.00014s] ()
# 2024-07-20 00:22:58,095 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-20 00:22:58,096 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-20 00:22:58,096 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("code_types")
# 2024-07-20 00:22:58,096 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-20 00:22:58,096 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("code_types")
# 2024-07-20 00:22:58,096 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-20 00:22:58,097 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("codes")
# 2024-07-20 00:22:58,097 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-20 00:22:58,097 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("codes")
# 2024-07-20 00:22:58,097 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-20 00:22:58,097 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("series")
# 2024-07-20 00:22:58,097 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-20 00:22:58,098 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("series")
# 2024-07-20 00:22:58,098 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-20 00:22:58,098 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("segments")
# 2024-07-20 00:22:58,098 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-20 00:22:58,098 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("segments")
# 2024-07-20 00:22:58,099 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-20 00:22:58,099 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("elements")
# 2024-07-20 00:22:58,099 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-20 00:22:58,099 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("elements")
# 2024-07-20 00:22:58,099 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-20 00:22:58,100 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("annotations")
# 2024-07-20 00:22:58,100 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-20 00:22:58,100 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("annotations")
# 2024-07-20 00:22:58,100 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-20 00:22:58,101 INFO sqlalchemy.engine.Engine
# CREATE TABLE code_types (
# 	type_id INTEGER NOT NULL,
# 	type_name TEXT NOT NULL,
# 	PRIMARY KEY (type_id),
# 	UNIQUE (type_name)
# )
#
#
# 2024-07-20 00:22:58,101 INFO sqlalchemy.engine.Engine [no key 0.00023s] ()
# 2024-07-20 00:22:58,102 INFO sqlalchemy.engine.Engine
# CREATE TABLE series (
# 	series_id INTEGER NOT NULL,
# 	series_title TEXT NOT NULL,
# 	PRIMARY KEY (series_id)
# )
#
#
# 2024-07-20 00:22:58,102 INFO sqlalchemy.engine.Engine [no key 0.00017s] ()
# 2024-07-20 00:22:58,103 INFO sqlalchemy.engine.Engine
# CREATE TABLE codes (
# 	code_id INTEGER NOT NULL,
# 	term TEXT NOT NULL,
# 	description TEXT,
# 	type_id INTEGER,
# 	reference TEXT,
# 	coordinates TEXT,
# 	PRIMARY KEY (code_id),
# 	UNIQUE (term),
# 	FOREIGN KEY(type_id) REFERENCES code_types (type_id)
# )
#
#
# 2024-07-20 00:22:58,104 INFO sqlalchemy.engine.Engine [no key 0.00022s] ()
# 2024-07-20 00:22:58,105 INFO sqlalchemy.engine.Engine
# CREATE TABLE segments (
# 	segment_id INTEGER NOT NULL,
# 	segment_title TEXT NOT NULL,
# 	series_id INTEGER,
# 	PRIMARY KEY (segment_id),
# 	UNIQUE (segment_title),
# 	FOREIGN KEY(series_id) REFERENCES series (series_id)
# )
#
#
# 2024-07-20 00:22:58,105 INFO sqlalchemy.engine.Engine [no key 0.00022s] ()
# 2024-07-20 00:22:58,107 INFO sqlalchemy.engine.Engine
# CREATE TABLE elements (
# 	element_id INTEGER NOT NULL,
# 	element_text TEXT NOT NULL,
# 	segment_id INTEGER,
# 	PRIMARY KEY (element_id),
# 	FOREIGN KEY(segment_id) REFERENCES segments (segment_id)
# )
#
#
# 2024-07-20 00:22:58,107 INFO sqlalchemy.engine.Engine [no key 0.00029s] ()
# 2024-07-20 00:22:58,109 INFO sqlalchemy.engine.Engine
# CREATE TABLE annotations (
# 	annotation_id INTEGER NOT NULL,
# 	element_id INTEGER,
# 	code_id INTEGER,
# 	PRIMARY KEY (annotation_id),
# 	CONSTRAINT _element_code_uc UNIQUE (element_id, code_id),
# 	FOREIGN KEY(element_id) REFERENCES elements (element_id),
# 	FOREIGN KEY(code_id) REFERENCES codes (code_id)
# )
#
#
# 2024-07-20 00:22:58,109 INFO sqlalchemy.engine.Engine [no key 0.00019s] ()
# 2024-07-20 00:22:58,110 INFO sqlalchemy.engine.Engine COMMIT

# %%
from sqlalchemy import func
from sqlalchemy.orm import Session
from sqlalchemy.ext.declarative import DeclarativeMeta
from sqlalchemy.exc import IntegrityError
from typing import Any, Hashable

# Define a function to insert data from a DataFrame
def insert_data(df: pd.DataFrame, model: DeclarativeMeta, session: Session) -> None:
    data: list[dict[Hashable, Any]] = df.to_dict(orient='records') # type: ignore
    
    try:
        session.bulk_insert_mappings(model, data) # type: ignore
        session.commit()
    except IntegrityError as e:
        print(f"Unique constraint violation: {e}")
        session.rollback()

# Insert data into the code_types table
insert_data(code_type_df, CodeType, session)

# Insert data into the codes table
insert_data(codes_df, Code, session)

# Insert data into the series table
insert_data(series_df, Series, session)

# Insert data into the segments table
insert_data(segment_df, Segment, session)

# Insert data into the elements table
insert_data(elements_df, Element, session)

# Insert data into the annotations table
insert_data(annotations_df, Annotation, session)

# Close the session
session.close()
# Out:
# 2024-07-20 00:22:58,121 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-20 00:22:58,122 INFO sqlalchemy.engine.Engine INSERT INTO code_types (type_id, type_name) VALUES (?, ?)
# 2024-07-20 00:22:58,122 INFO sqlalchemy.engine.Engine [generated in 0.00028s] [(1, 'Person'), (2, 'Events and Periods'), (3, 'Group'), (4, 'Concept: Cultural and Societal'), (5, 'Geography'), (6, 'Concept: Political and Social'), (7, 'Concept: Economics and Infrastructure'), (8, 'Concept: Terrorism and Security')  ... displaying 10 of 16 total bound parameter sets ...  (15, 'Education and Institutions'), (16, 'Concept: Legal')]
# 2024-07-20 00:22:58,122 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-20 00:22:58,125 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-20 00:22:58,127 INFO sqlalchemy.engine.Engine INSERT INTO codes (code_id, term, description, type_id, reference, coordinates) VALUES (?, ?, ?, ?, ?, ?)
# 2024-07-20 00:22:58,127 INFO sqlalchemy.engine.Engine [generated in 0.00075s] [(875, 'Zelimkhan Yandarbiyev', 'A Chechen writer and politician who served as President of the Chechen Republic of Ichkeria', 1, 'https://en.wikipedia.org/wiki/Zelimkhan_Yandarbiyev', nan), (338, "Zarqawi's cause", 'Referring to the jihadist campaign led by Abu Musab al-Zarqawi, the leader of al-Qaeda in Iraq during the Iraq War.', 1, 'https://en.wikipedia.org/wiki/Abu_Musab_al-Zarqawi', nan), (837, 'Yugoslavia', 'A historical country in Southeastern and Central Europe for most of the 20th century, until its dissolution in the early 1990s.', 2, 'https://en.wikipedia.org/wiki/Yugoslavia', nan), (618, "YPG (People's Protection Units)", 'A Kurdish militia in Syria that controls a portion of Syrian territory and fought against ISIS.', 3, 'https://en.wikipedia.org/wiki/People%27s_Protection_Units', nan), (434, 'Yemeni Tribalism', "The strong tribal culture within Yemen that significantly influences the country's social and political dynamics.", 4, 'https://en.wikipedia.org/wiki/Yemeni_Crisis_(2011–present)', nan), (444, 'Yemeni Sectarian Landscape', 'The religious and sectarian divisions within Yemen, including various Islamic sects such as Sunnis, Zaidis, and Jarudi Zaidis.', 4, 'https://en.wikipedia.org/wiki/Religion_in_Yemen', nan), (503, 'Yemeni Coast', 'The coastline of Yemen, which is strategically important due to its proximity to key shipping routes and the Bab-el-Mandeb Strait.', 5, 'https://en.wikipedia.org/wiki/Geography_of_Yemen', '14.4990, 46.3666'), (440, 'Yemeni AK-47 Culture', 'The widespread possession and cultural significance of AK-47s among civilians in Yemen.', 4, 'https://en.wikipedia.org/wiki/Yemeni_Crisis_(2011–present)', nan)  ... displaying 10 of 422 total bound parameter sets ...  (913, '2008 Financial Crisis', 'A severe worldwide economic crisis that occurred in the late 2000s, related to the subprime mortgage market and financial instruments like derivatives.', 2, 'https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%932008', nan), (64, '9/11', 'A series of coordinated terrorist attacks by the Islamist terrorist group al-Qaeda against the United States on the morning of Tuesday, September 11, 2001.', 8, 'https://en.wikipedia.org/wiki/September_11_attacks', nan)]
# 2024-07-20 00:22:58,129 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-20 00:22:58,130 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-20 00:22:58,130 INFO sqlalchemy.engine.Engine INSERT INTO series (series_id, series_title) VALUES (?, ?)
# 2024-07-20 00:22:58,131 INFO sqlalchemy.engine.Engine [generated in 0.00020s] (1, 'Conflicted Podcast')
# 2024-07-20 00:22:58,131 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-20 00:22:58,132 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-20 00:22:58,132 INFO sqlalchemy.engine.Engine INSERT INTO segments (segment_id, segment_title, series_id) VALUES (?, ?, ?)
# 2024-07-20 00:22:58,133 INFO sqlalchemy.engine.Engine [generated in 0.00022s] [(1, 'S1E1 - 9/11', 1), (2, 'S1E2 - War on Terror', 1), (3, 'S1E3 - Iraq', 1), (4, 'S1E4 - Yemen', 1), (5, 'S1E5 - Syria', 1), (6, 'S1E6 - Returning Jihadists', 1), (7, 'S2E1 - World War Iran', 1), (8, 'S2E2 - New World Order', 1)  ... displaying 10 of 51 total bound parameter sets ...  (50, "S4E18: Hezbollah: Israel's Menace or Lebanon's Defender?", 1), (51, 'S4E19: Yemen: In the Shadow of the Imam', 1)]
# 2024-07-20 00:22:58,133 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-20 00:22:58,143 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-20 00:22:58,188 INFO sqlalchemy.engine.Engine INSERT INTO elements (element_id, element_text, segment_id) VALUES (?, ?, ?)
# 2024-07-20 00:22:58,188 INFO sqlalchemy.engine.Engine [generated in 0.00941s] [(7, "Thomas Small Let's get into it. ", 1), (8, "We'll start this series with an event that catapulted the conflicts of the Middle East into the global consciousness: The Twin Tower attacks on September 11th. ", 1), (9, 'Aimen Dean Okay.', 1), (10, "Thomas Small Right. So, we're just starting. ", 1), (11, 'Aimen Dean Yeah. Go ahead.', 1), (12, "Thomas Small Aimen Dean. How do I introduce Aimen Dean? There is literally no one on Planet Earth like Aimen Dean. Saudi-born, but Bahraini nationali ... (904 characters truncated) ... s his former al-Qaeda – the surviving former al-Qaeda jihadists and their followers want to kill him dead for stabbing them in the back. Aimen Dean. ", 1), (13, 'Aimen Dean Well, that was, you know, a rather ominous introduction. Well, Thomas, how am I going to introduce you? Even after years of knowing you—po ... (715 characters truncated) ... e nuances, the… Understand the Bedouin culture?\' You know, if I want to describe Thomas Small in few words, I would say that he is no small at all. ', 1), (14, "Thomas Small Well, here's the thing, Aimen. I met you and I felt weirdly like I had met some kind of spiritual brother.", 1)  ... displaying 10 of 12396 total bound parameter sets ...  (15609, 'There you will find other fans of the show engaging in heated debates, enlightening conversations, and just generally geeking out over Conflicted related topics.', 51), (15610, 'Conflicted is a Message Heard production. This episode was produced and edited by Harry Stott. Sandra Ferrari is our executive producer. Our theme music is by Matt Huxley and Tom Biddle.', 51)]
# 2024-07-20 00:22:58,205 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-20 00:22:58,212 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-20 00:22:58,222 INFO sqlalchemy.engine.Engine INSERT INTO annotations (annotation_id, element_id, code_id) VALUES (?, ?, ?)
# 2024-07-20 00:22:58,222 INFO sqlalchemy.engine.Engine [generated in 0.00446s] [(0, 12, 12), (1, 12, 35), (2, 12, 42), (3, 12, 70), (4, 12, 381), (5, 12, 60), (6, 12, 48), (7, 12, 725)  ... displaying 10 of 5505 total bound parameter sets ...  (5503, 15603, 719), (5504, 15606, 719)]
# 2024-07-20 00:22:58,228 INFO sqlalchemy.engine.Engine COMMIT
# /var/folders/qf/j616b9d53yn77zcpky42s5r40000gn/T/ipykernel_6537/2863780145.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   data: list[dict[Hashable, Any]] = df.to_dict(orient='records') # type: ignore

# %%
# Step 1: Select a random code item
random_code = session.query(Code).order_by(func.random()).first()

if random_code:
    code_id = random_code.code_id
    print("Random Code ID:")
    print(code_id)
    print("Random Code Item:")
    print(random_code)

    # Step 2: Find all annotations associated with the selected code
    annotations = session.query(Annotation).filter(Annotation.code_id == code_id).all()

    if annotations:
        print('----\nRESULTS\n-----')
        for annotation in annotations:
            print("\nAssociated Annotation:")
            print(annotation)

            # Step 3: Retrieve all elements associated with those annotations
            element_id = annotation.element_id
            element = session.query(Element).filter(Element.element_id == element_id).first()

            if element:
                print("\nAssociated Element:")
                print(element)
            else:
                print("No associated elements found.")
            print("\n")
            print("--------------------------------------------------")
            print("\n")
    else:
        print("No associated annotations found.")
else:
    print("No codes found in the database.")
# Out:
# 2024-07-20 00:22:58,234 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-20 00:22:58,236 INFO sqlalchemy.engine.Engine SELECT codes.code_id AS codes_code_id, codes.term AS codes_term, codes.description AS codes_description, codes.type_id AS codes_type_id, codes.reference AS codes_reference, codes.coordinates AS codes_coordinates
# FROM codes ORDER BY random()
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,236 INFO sqlalchemy.engine.Engine [generated in 0.00048s] (1, 0)
# Random Code ID:
# 670
# Random Code Item:
# Code(code_id=670, term=Salafism, description=A reform branch within Sunni Islam that advocates returning to the traditions of the "devout ancestors" (the salaf)., type_id=10, reference=https://en.wikipedia.org/wiki/Salafism, coordinates=None)
# 2024-07-20 00:22:58,238 INFO sqlalchemy.engine.Engine SELECT annotations.annotation_id AS annotations_annotation_id, annotations.element_id AS annotations_element_id, annotations.code_id AS annotations_code_id
# FROM annotations
# WHERE annotations.code_id = ?
# 2024-07-20 00:22:58,238 INFO sqlalchemy.engine.Engine [generated in 0.00034s] (670,)
# ----
# RESULTS
# -----
#
# Associated Annotation:
# Annotation(annotation_id=2094, element_id=3802, code_id=670)
# 2024-07-20 00:22:58,240 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,240 INFO sqlalchemy.engine.Engine [generated in 0.00029s] (3802, 1, 0)
#
# Associated Element:
# Element(element_id=3802, element_text=AIMEN: Oh he brought, you know, quite a few preachers from Saudi Arabia. Uh, of course, with the disapproval of the Saudi government. Many of them became, you know, wanted by the Saudi government because the Saudi government and Russia had a good relationship at the time. So, they were brought in order to teach a new generation of Chechens and Dagestanis other Caucuses minority people the principles of Salafism so they spread it and therefore dilute the Sufi character of the Caucus’s Muslims., segment_id=9)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2483, element_id=6490, code_id=670)
# 2024-07-20 00:22:58,241 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,241 INFO sqlalchemy.engine.Engine [cached since 0.001208s ago] (6490, 1, 0)
#
# Associated Element:
# Element(element_id=6490, element_text=And – and – and by Salafist, we mentioned earlier how the Taliban are attached to the Deobandi movement. Salafism is a different movement. It comes from the Arab part of the Middle East. It is associated with the Muslim Brotherhood, with characters like Sayyid Qutb. It comes with – with a fusion with Saudi-inflicted Wahhabism., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2488, element_id=6492, code_id=670)
# 2024-07-20 00:22:58,242 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,242 INFO sqlalchemy.engine.Engine [cached since 0.001859s ago] (6492, 1, 0)
#
# Associated Element:
# Element(element_id=6492, element_text=Aimen Dean Exactly. You know, while Al-Qaeda was tolerant towards Deobandism, and Deobandis were tolerant towards Al-Qaeda, because Al-Qaeda did not represent a rejectionist Jihadi Salafism towards other Suni trends, ISIS, however, completely, re—. you know, they rejected Al-Qaeda themselves, actually, and they agreed that Al-Qaeda were kafir. You know, they were, you know, infidels. They were apostates., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2722, element_id=7057, code_id=670)
# 2024-07-20 00:22:58,242 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,242 INFO sqlalchemy.engine.Engine [cached since 0.002443s ago] (7057, 1, 0)
#
# Associated Element:
# Element(element_id=7057, element_text=Ibn Taymiyyah, you know, the famous grandfather of Salafism, he fought against King Kazan and the Ilkhanate Mongols and issued fatwas that they were not proper Muslims, because they were incorporating parts of the Yassa—you know, Genghis Khan, you know, law—into Islam. And so, he declared them to be, you know, non-proper – not proper Muslims. He excommunicated them and then he fought against them. He declared jihad against them. So, no. , segment_id=16)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=3759, element_id=10821, code_id=670)
# 2024-07-20 00:22:58,243 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,243 INFO sqlalchemy.engine.Engine [cached since 0.003128s ago] (10821, 1, 0)
#
# Associated Element:
# Element(element_id=10821, element_text=Thomas:    The other great influence on Abdullah Azzam, though as you say, yes, not as much as Sayyid Qutb was what I'm going to call here, and this might make you bristle Aimen, Wahhabi Salafism., segment_id=30)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=3762, element_id=10823, code_id=670)
# 2024-07-20 00:22:58,244 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,244 INFO sqlalchemy.engine.Engine [cached since 0.003778s ago] (10823, 1, 0)
#
# Associated Element:
# Element(element_id=10823, element_text=But at the end of the sixties, Abdullah Azzam spent a year in Saudi Arabia teaching. And while he was there, he was exposed to that form of Islam, the form that's practiced there in all three varieties; Wahhabi Salafism, and in some important respects, Salafism deviates or is in disagreement with Muslim Brotherhood ideas. , segment_id=30)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=3764, element_id=10826, code_id=670)
# 2024-07-20 00:22:58,244 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,244 INFO sqlalchemy.engine.Engine [cached since 0.004461s ago] (10826, 1, 0)
#
# Associated Element:
# Element(element_id=10826, element_text=Aimen:    Yes. Salafism is split into three, for the benefit of the dear listener. You have the quietest or the royalist Salafism, which we see practiced by the Saudi state right now, and the official religious institutions there., segment_id=30)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=3766, element_id=10827, code_id=670)
# 2024-07-20 00:22:58,245 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,245 INFO sqlalchemy.engine.Engine [cached since 0.005086s ago] (10827, 1, 0)
#
# Associated Element:
# Element(element_id=10827, element_text=Then you have the Salafist jihadism where the militant wing of the Muslim Brotherhood merged with Salafism and Wahhabism and formed that hybrid., segment_id=30)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=3768, element_id=10828, code_id=670)
# 2024-07-20 00:22:58,245 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,246 INFO sqlalchemy.engine.Engine [cached since 0.005678s ago] (10828, 1, 0)
#
# Associated Element:
# Element(element_id=10828, element_text=And then you have the moderate wing of the Muslim Brotherhood, the political activist wing of the Muslim Brotherhood emerging and forming that hybrid connection with Salafism and creating what I call the activist political Salafism., segment_id=30)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=3770, element_id=10829, code_id=670)
# 2024-07-20 00:22:58,246 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,253 INFO sqlalchemy.engine.Engine [cached since 0.01258s ago] (10829, 1, 0)
#
# Associated Element:
# Element(element_id=10829, element_text=So, these are the three strands and, in my opinion, Abdullah Azzam in his own person, in his own form was one of the earliest convert to the idea of Jihadi Salafism., segment_id=30)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=4073, element_id=11352, code_id=670)
# 2024-07-20 00:22:58,274 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,274 INFO sqlalchemy.engine.Engine [cached since 0.03449s ago] (11352, 1, 0)
#
# Associated Element:
# Element(element_id=11352, element_text=And so, they came back to Algeria and they started spreading the hybrid belief between Muslim Brotherhood and political Salafism, as well as Jihadi Salafism. And all of these factors conspire together to create the perfect storm in Algeria by 1988., segment_id=31)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=4079, element_id=11362, code_id=670)
# 2024-07-20 00:22:58,275 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,276 INFO sqlalchemy.engine.Engine [cached since 0.03589s ago] (11362, 1, 0)
#
# Associated Element:
# Element(element_id=11362, element_text=But this is not the Islam of Sufism which is quietest and focusing on the spiritual wellbeing of the individual rather than the entire society. No, this is a new brand of Islamism. This is political Salafism, supported by Jihadi Salafism., segment_id=31)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=4230, element_id=12278, code_id=670)
# 2024-07-20 00:22:58,276 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,277 INFO sqlalchemy.engine.Engine [cached since 0.03683s ago] (12278, 1, 0)
#
# Associated Element:
# Element(element_id=12278, element_text=And I think it's important to point out before we move on with Ahmad's story, that he, along with a lot of very pious people of any religious tradition, but certainly within Salafism, he had a religious mentality that emphasised detachment from the world. He did not want to become too involved in the world, which was coming to an end., segment_id=36)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=4241, element_id=12477, code_id=670)
# 2024-07-20 00:22:58,277 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,278 INFO sqlalchemy.engine.Engine [cached since 0.03789s ago] (12477, 1, 0)
#
# Associated Element:
# Element(element_id=12477, element_text=It is from this school that what is known as Salafism emerges, it is from the Hanbali School. The school, which to this day is the official Islamic school that governs a country like Saudi Arabia that Muḥammad ibn ʿAbd al-Wahhāb, the founder of Wahhabism, was a member of this school. It's from this school that the modern fundamentalist movement, more or less draws its inspiration., segment_id=36)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=4269, element_id=12543, code_id=670)
# 2024-07-20 00:22:58,279 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,279 INFO sqlalchemy.engine.Engine [cached since 0.03933s ago] (12543, 1, 0)
#
# Associated Element:
# Element(element_id=12543, element_text=I think the colonial period in the Middle East, the abolition of the Ottoman Caliphate in the 1920s, everything that's followed on from that, all of the instability and the political wrangling and the rise of neo-Salafism invoking Ibn Taymiyyah's memory. It's so similar to that world, Ibn Taymiyyah’s world, wouldn't you say?, segment_id=37)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=4362, element_id=12657, code_id=670)
# 2024-07-20 00:22:58,280 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,281 INFO sqlalchemy.engine.Engine [cached since 0.0407s ago] (12657, 1, 0)
#
# Associated Element:
# Element(element_id=12657, element_text=Now mix in the Absolutist Salafism and you have a powder keg about to explode and this is what's going to happen., segment_id=37)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=4546, element_id=12973, code_id=670)
# 2024-07-20 00:22:58,281 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,283 INFO sqlalchemy.engine.Engine [cached since 0.04336s ago] (12973, 1, 0)
#
# Associated Element:
# Element(element_id=12973, element_text=Aimen: Absolutely. So, ad-Daghistani Al-Dimashqi was pretty much influenced heavily by ibn Taymiyyah’s brand of Salafism. And he imparted that and imprinted that on his young, brand-new student, Muhammad ibn 'Abd al-Wahhab. Muhammad ibn 'Abd al-Wahhab spent considerable time with ad-Daghistani Al-Dimashqi in Medina. And then after that he travelled to Basra., segment_id=39)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=4609, element_id=13350, code_id=670)
# 2024-07-20 00:22:58,285 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,285 INFO sqlalchemy.engine.Engine [cached since 0.04537s ago] (13350, 1, 0)
#
# Associated Element:
# Element(element_id=13350, element_text=Aimen: Indeed. He was the product of his time, but also, we have to state that he comes from a Sufi family. He was never a Hanbali or a Salafi. Nonetheless, this man, the most unlikely of people, would have the greatest impact on Salafism and Hanbali Salafism to be more precise in the 20th and the 21st century., segment_id=41)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=4755, element_id=13673, code_id=670)
# 2024-07-20 00:22:58,286 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,287 INFO sqlalchemy.engine.Engine [cached since 0.04671s ago] (13673, 1, 0)
#
# Associated Element:
# Element(element_id=13673, element_text=The second chapter there talks about a unique Qur’anic generation. So, we of course, declaring his Salafism., segment_id=42)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=4770, element_id=13698, code_id=670)
# 2024-07-20 00:22:58,287 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,288 INFO sqlalchemy.engine.Engine [cached since 0.04769s ago] (13698, 1, 0)
#
# Associated Element:
# Element(element_id=13698, element_text=Aimen: So, imagine if Wahhabism and Salafism was an egg, then Sayyid was a sperm that came in, fertilised it with a political framework, with an ideological bent in order to propel it forward as a movement, to create that embryonic stage towards a proper militant Islamic revolutionary movement., segment_id=42)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=4774, element_id=13700, code_id=670)
# 2024-07-20 00:22:58,288 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,289 INFO sqlalchemy.engine.Engine [cached since 0.04861s ago] (13700, 1, 0)
#
# Associated Element:
# Element(element_id=13700, element_text=Sayyid Qutb took already existing Salafism and breathed ideological fire into it, forming it into a political framework giving it a political goal. The kingdom of God on earth that inspired not only Al-Qaeda, not only the Egyptian Islamic jihad, not only al-Shabaab, but also the Ayatollah Khomeini and the Iranian Revolution., segment_id=42)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=4776, element_id=13701, code_id=670)
# 2024-07-20 00:22:58,289 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,289 INFO sqlalchemy.engine.Engine [cached since 0.04933s ago] (13701, 1, 0)
#
# Associated Element:
# Element(element_id=13701, element_text=But also take your pick, they’ve all been influenced by Sayyid Qutb. He gave Salafism, he gave that psychological spiritual temperament that we've been exploring. The temperament towards literalism, the temperament towards purity, the temperament towards nostalgia, the temperament towards withdrawing from the world, which is perceived as corrupt and corrupting., segment_id=42)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=4834, element_id=13794, code_id=670)
# 2024-07-20 00:22:58,290 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,290 INFO sqlalchemy.engine.Engine [cached since 0.05006s ago] (13794, 1, 0)
#
# Associated Element:
# Element(element_id=13794, element_text=So, this strange mixture, it's a kind of mixture of nationalism, pan-Islamic solidarity, anti-colonialism. It's a mixture allied with Salafism, with this idea that modern Islam has somehow gone astray. And we must look to the sources of the religion to renew it, to purify it., segment_id=43)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=4992, element_id=14014, code_id=670)
# 2024-07-20 00:22:58,291 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,291 INFO sqlalchemy.engine.Engine [cached since 0.05086s ago] (14014, 1, 0)
#
# Associated Element:
# Element(element_id=14014, element_text=Thomas: But are you saying then that there is no way to determine what correct Islam is? I don't think you believe that you are to some extent a Salafi. You describe yourself as a Salafi. Salafism in its very essence is about saying this is what Islam truly is. And much that has passed under the name of Islam throughout history is not Islam. So, what's the difference?, segment_id=44)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=5119, element_id=14566, code_id=670)
# 2024-07-20 00:22:58,291 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-20 00:22:58,291 INFO sqlalchemy.engine.Engine [cached since 0.05147s ago] (14566, 1, 0)
#
# Associated Element:
# Element(element_id=14566, element_text=Aimen: Indeed, because it was of course, the end of Sayyid Qutb’s life, his ideas matured so much into Sunni Salafism and by then, basically he abandoned a lot of the Islamic unity that he was calling for by the mid-60s., segment_id=47)
#
#
# --------------------------------------------------
