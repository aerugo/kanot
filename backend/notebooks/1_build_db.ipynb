# %% [markdown]
# # Import data from Conflicted Glossary

# %%
import pandas as pd

# Load the CSV files into DataFrames
codes_df = pd.read_csv('../_temp/glossary.csv')  # type: ignore
elements_df = pd.read_csv('../_temp/transcripts.csv')  # type: ignore

# Rename columns according to the provided mapping
codes_df = codes_df.rename(columns={
    'Glossary ID': 'code_id',
    'Term': 'term',
    'Description': 'description',
    'Type': 'type',
    'Read more': 'reference',
    'Lat/Long': 'coordinates'
})

elements_df = elements_df.rename(columns={
    'Text ID': 'element_id',
    'Text': 'element_text',
    'Episode ID': 'segment_id',
    'Episode': 'segment_title',
    'Glossary IDs': 'code_ids'
})
# drop the columns that are not element_id, element_text, segment_id, segment_title, code_ids
elements_df = elements_df[['element_id', 'element_text', 'segment_id', 'segment_title', 'code_ids']]

elements_df['code_ids'] = elements_df['code_ids'].fillna('') # type: ignore

# remove any rows in the elements_df where the element_text is empty
elements_df = elements_df[elements_df['element_text'].notnull()]

# create a dataframe with all unique segment_id and segment_title
segment_df = elements_df[['segment_id', 'segment_title']].drop_duplicates()

# create a dataframe series_df with autoincrementing column series_id and series_title and add one row with series_title = 'Conflicted Podcast'
series_df = pd.DataFrame({'series_id': [1], 'series_title': ['Conflicted Podcast']})

# add a column series_id to the segment_df dataframe and set the value to 1 for all rows
segment_df['series_id'] = 1

# create a dataframe with all unique glossary type
code_type_df = codes_df[['type']].drop_duplicates()
# rename the column to type_name
code_type_df = code_type_df.rename(columns={'type': 'type_name'})
# create an incrementing type_id column
code_type_df['type_id'] = range(1, len(code_type_df) + 1)

# Create a column type_id in the codes_df dataframe and map the type_name to the type_id
# Merge the code_type_df with the codes_df on type = type_name
codes_df = codes_df.merge(code_type_df, left_on='type', right_on='type_name', how='left') # type: ignore
codes_df = codes_df.rename(columns={'type_name': 'type_id'})
codes_df = codes_df[['code_id', 'term', 'description', 'type_id', 'reference', 'coordinates']]

# %%
# Create a new DataFrame annotations_df with columns element_id, code_id
annotations_df = pd.DataFrame(columns=['element_id', 'code_id'])

# Iterate over each row in elements_df and add rows to annotations_df
rows_to_add = []
for index, row in elements_df.iterrows():
    element_id = row['element_id']
    code_ids = row['code_ids'].split(';')
    for code_id in code_ids if code_ids != [''] else []:
        code_id = int(code_id)
        rows_to_add.append({'element_id': element_id, 'code_id': code_id})

elements_df.drop(columns=['code_ids', 'segment_title'], inplace=True) # type: ignore

# Convert list of rows to DataFrame and concatenate
annotations_df = pd.concat([annotations_df, pd.DataFrame(rows_to_add)], ignore_index=True)

# Convert code_id to int
annotations_df['code_id'] = annotations_df['code_id'].astype(int)

# Add a column annotation_id to annotations_df
annotations_df['annotation_id'] = annotations_df.index

# %% [markdown]
# # Define Database

# %%
from kanot.db.schema import create_database, drop_database, CodeType, Code, Series, Segment, Element, Annotation
from sqlalchemy import create_engine, Engine
from sqlalchemy.orm import sessionmaker

# Create a connection to the SQLite database
engine: Engine = create_engine('sqlite:///../local_database.db', echo=True)
MySession = sessionmaker(bind=engine)
session = MySession()

drop = True
if drop:
    # Drop all the tables in the database
    drop_database(engine)

# Create the tables in the database
create_database(engine)
# Out:
# 2024-07-19 01:47:46,928 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-19 01:47:46,928 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("code_types")
# 2024-07-19 01:47:46,928 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-19 01:47:46,929 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("codes")
# 2024-07-19 01:47:46,929 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-19 01:47:46,929 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("series")
# 2024-07-19 01:47:46,930 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-19 01:47:46,930 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("segments")
# 2024-07-19 01:47:46,930 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-19 01:47:46,930 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("elements")
# 2024-07-19 01:47:46,931 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-19 01:47:46,931 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("annotations")
# 2024-07-19 01:47:46,931 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-19 01:47:46,931 INFO sqlalchemy.engine.Engine
# DROP TABLE annotations
# 2024-07-19 01:47:46,932 INFO sqlalchemy.engine.Engine [no key 0.00020s] ()
# 2024-07-19 01:47:46,933 INFO sqlalchemy.engine.Engine
# DROP TABLE elements
# 2024-07-19 01:47:46,933 INFO sqlalchemy.engine.Engine [no key 0.00015s] ()
# 2024-07-19 01:47:46,935 INFO sqlalchemy.engine.Engine
# DROP TABLE segments
# 2024-07-19 01:47:46,935 INFO sqlalchemy.engine.Engine [no key 0.00023s] ()
# 2024-07-19 01:47:46,936 INFO sqlalchemy.engine.Engine
# DROP TABLE codes
# 2024-07-19 01:47:46,936 INFO sqlalchemy.engine.Engine [no key 0.00014s] ()
# 2024-07-19 01:47:46,937 INFO sqlalchemy.engine.Engine
# DROP TABLE series
# 2024-07-19 01:47:46,937 INFO sqlalchemy.engine.Engine [no key 0.00016s] ()
# 2024-07-19 01:47:46,937 INFO sqlalchemy.engine.Engine
# DROP TABLE code_types
# 2024-07-19 01:47:46,938 INFO sqlalchemy.engine.Engine [no key 0.00023s] ()
# 2024-07-19 01:47:46,938 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-19 01:47:46,939 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-19 01:47:46,939 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("code_types")
# 2024-07-19 01:47:46,939 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-19 01:47:46,939 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("code_types")
# 2024-07-19 01:47:46,939 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-19 01:47:46,940 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("codes")
# 2024-07-19 01:47:46,940 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-19 01:47:46,940 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("codes")
# 2024-07-19 01:47:46,940 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-19 01:47:46,941 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("series")
# 2024-07-19 01:47:46,941 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-19 01:47:46,941 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("series")
# 2024-07-19 01:47:46,941 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-19 01:47:46,942 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("segments")
# 2024-07-19 01:47:46,942 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-19 01:47:46,942 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("segments")
# 2024-07-19 01:47:46,942 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-19 01:47:46,942 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("elements")
# 2024-07-19 01:47:46,943 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-19 01:47:46,943 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("elements")
# 2024-07-19 01:47:46,943 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-19 01:47:46,943 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("annotations")
# 2024-07-19 01:47:46,943 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-19 01:47:46,944 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("annotations")
# 2024-07-19 01:47:46,944 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-19 01:47:46,944 INFO sqlalchemy.engine.Engine
# CREATE TABLE code_types (
# 	type_id INTEGER NOT NULL,
# 	type_name TEXT NOT NULL,
# 	PRIMARY KEY (type_id),
# 	UNIQUE (type_name)
# )
#
#
# 2024-07-19 01:47:46,944 INFO sqlalchemy.engine.Engine [no key 0.00022s] ()
# 2024-07-19 01:47:46,946 INFO sqlalchemy.engine.Engine
# CREATE TABLE series (
# 	series_id INTEGER NOT NULL,
# 	series_title TEXT NOT NULL,
# 	PRIMARY KEY (series_id)
# )
#
#
# 2024-07-19 01:47:46,946 INFO sqlalchemy.engine.Engine [no key 0.00021s] ()
# 2024-07-19 01:47:46,947 INFO sqlalchemy.engine.Engine
# CREATE TABLE codes (
# 	code_id INTEGER NOT NULL,
# 	term TEXT NOT NULL,
# 	description TEXT,
# 	type_id INTEGER,
# 	reference TEXT,
# 	coordinates TEXT,
# 	PRIMARY KEY (code_id),
# 	UNIQUE (term),
# 	FOREIGN KEY(type_id) REFERENCES code_types (type_id)
# )
#
#
# 2024-07-19 01:47:46,947 INFO sqlalchemy.engine.Engine [no key 0.00018s] ()
# 2024-07-19 01:47:46,948 INFO sqlalchemy.engine.Engine
# CREATE TABLE segments (
# 	segment_id INTEGER NOT NULL,
# 	segment_title TEXT NOT NULL,
# 	series_id INTEGER,
# 	PRIMARY KEY (segment_id),
# 	UNIQUE (segment_title),
# 	FOREIGN KEY(series_id) REFERENCES series (series_id)
# )
#
#
# 2024-07-19 01:47:46,948 INFO sqlalchemy.engine.Engine [no key 0.00021s] ()
# 2024-07-19 01:47:46,949 INFO sqlalchemy.engine.Engine
# CREATE TABLE elements (
# 	element_id INTEGER NOT NULL,
# 	element_text TEXT NOT NULL,
# 	segment_id INTEGER,
# 	PRIMARY KEY (element_id),
# 	FOREIGN KEY(segment_id) REFERENCES segments (segment_id)
# )
#
#
# 2024-07-19 01:47:46,949 INFO sqlalchemy.engine.Engine [no key 0.00017s] ()
# 2024-07-19 01:47:46,950 INFO sqlalchemy.engine.Engine
# CREATE TABLE annotations (
# 	annotation_id INTEGER NOT NULL,
# 	element_id INTEGER,
# 	code_id INTEGER,
# 	PRIMARY KEY (annotation_id),
# 	CONSTRAINT _element_code_uc UNIQUE (element_id, code_id),
# 	FOREIGN KEY(element_id) REFERENCES elements (element_id),
# 	FOREIGN KEY(code_id) REFERENCES codes (code_id)
# )
#
#
# 2024-07-19 01:47:46,950 INFO sqlalchemy.engine.Engine [no key 0.00022s] ()
# 2024-07-19 01:47:46,951 INFO sqlalchemy.engine.Engine COMMIT

# %%
from sqlalchemy import func
from sqlalchemy.orm import Session
from sqlalchemy.ext.declarative import DeclarativeMeta
from sqlalchemy.exc import IntegrityError
from typing import Any, Hashable

# Define a function to insert data from a DataFrame
def insert_data(df: pd.DataFrame, model: DeclarativeMeta, session: Session) -> None:
    data: list[dict[Hashable, Any]] = df.to_dict(orient='records') # type: ignore
    
    try:
        session.bulk_insert_mappings(model, data) # type: ignore
        session.commit()
    except IntegrityError as e:
        print(f"Unique constraint violation: {e}")
        session.rollback()

# Insert data into the code_types table
insert_data(code_type_df, CodeType, session)

# Insert data into the codes table
insert_data(codes_df, Code, session)

# Insert data into the series table
insert_data(series_df, Series, session)

# Insert data into the segments table
insert_data(segment_df, Segment, session)

# Insert data into the elements table
insert_data(elements_df, Element, session)

# Insert data into the annotations table
insert_data(annotations_df, Annotation, session)

# Close the session
session.close()
# Out:
# 2024-07-19 01:47:46,962 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-19 01:47:46,963 INFO sqlalchemy.engine.Engine INSERT INTO code_types (type_id, type_name) VALUES (?, ?)
# 2024-07-19 01:47:46,964 INFO sqlalchemy.engine.Engine [generated in 0.00038s] [(1, 'Person'), (2, 'Events and Periods'), (3, 'Group'), (4, 'Concept: Cultural and Societal'), (5, 'Geography'), (6, 'Concept: Political and Social'), (7, 'Concept: Economics and Infrastructure'), (8, 'Concept: Terrorism and Security')  ... displaying 10 of 16 total bound parameter sets ...  (15, 'Education and Institutions'), (16, 'Concept: Legal')]
# 2024-07-19 01:47:46,965 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-19 01:47:46,972 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-19 01:47:46,974 INFO sqlalchemy.engine.Engine INSERT INTO codes (code_id, term, description, type_id, reference, coordinates) VALUES (?, ?, ?, ?, ?, ?)
# 2024-07-19 01:47:46,974 INFO sqlalchemy.engine.Engine [generated in 0.00085s] [(875, 'Zelimkhan Yandarbiyev', 'A Chechen writer and politician who served as President of the Chechen Republic of Ichkeria', 1, 'https://en.wikipedia.org/wiki/Zelimkhan_Yandarbiyev', nan), (338, "Zarqawi's cause", 'Referring to the jihadist campaign led by Abu Musab al-Zarqawi, the leader of al-Qaeda in Iraq during the Iraq War.', 1, 'https://en.wikipedia.org/wiki/Abu_Musab_al-Zarqawi', nan), (837, 'Yugoslavia', 'A historical country in Southeastern and Central Europe for most of the 20th century, until its dissolution in the early 1990s.', 2, 'https://en.wikipedia.org/wiki/Yugoslavia', nan), (618, "YPG (People's Protection Units)", 'A Kurdish militia in Syria that controls a portion of Syrian territory and fought against ISIS.', 3, 'https://en.wikipedia.org/wiki/People%27s_Protection_Units', nan), (434, 'Yemeni Tribalism', "The strong tribal culture within Yemen that significantly influences the country's social and political dynamics.", 4, 'https://en.wikipedia.org/wiki/Yemeni_Crisis_(2011–present)', nan), (444, 'Yemeni Sectarian Landscape', 'The religious and sectarian divisions within Yemen, including various Islamic sects such as Sunnis, Zaidis, and Jarudi Zaidis.', 4, 'https://en.wikipedia.org/wiki/Religion_in_Yemen', nan), (503, 'Yemeni Coast', 'The coastline of Yemen, which is strategically important due to its proximity to key shipping routes and the Bab-el-Mandeb Strait.', 5, 'https://en.wikipedia.org/wiki/Geography_of_Yemen', '14.4990, 46.3666'), (440, 'Yemeni AK-47 Culture', 'The widespread possession and cultural significance of AK-47s among civilians in Yemen.', 4, 'https://en.wikipedia.org/wiki/Yemeni_Crisis_(2011–present)', nan)  ... displaying 10 of 422 total bound parameter sets ...  (913, '2008 Financial Crisis', 'A severe worldwide economic crisis that occurred in the late 2000s, related to the subprime mortgage market and financial instruments like derivatives.', 2, 'https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%932008', nan), (64, '9/11', 'A series of coordinated terrorist attacks by the Islamist terrorist group al-Qaeda against the United States on the morning of Tuesday, September 11, 2001.', 8, 'https://en.wikipedia.org/wiki/September_11_attacks', nan)]
# 2024-07-19 01:47:46,976 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-19 01:47:46,978 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-19 01:47:46,978 INFO sqlalchemy.engine.Engine INSERT INTO series (series_id, series_title) VALUES (?, ?)
# 2024-07-19 01:47:46,979 INFO sqlalchemy.engine.Engine [generated in 0.00025s] (1, 'Conflicted Podcast')
# 2024-07-19 01:47:46,979 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-19 01:47:46,980 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-19 01:47:46,981 INFO sqlalchemy.engine.Engine INSERT INTO segments (segment_id, segment_title, series_id) VALUES (?, ?, ?)
# 2024-07-19 01:47:46,981 INFO sqlalchemy.engine.Engine [generated in 0.00032s] [(1, 'S1E1 - 9/11', 1), (2, 'S1E2 - War on Terror', 1), (3, 'S1E3 - Iraq', 1), (4, 'S1E4 - Yemen', 1), (5, 'S1E5 - Syria', 1), (6, 'S1E6 - Returning Jihadists', 1), (7, 'S2E1 - World War Iran', 1), (8, 'S2E2 - New World Order', 1)  ... displaying 10 of 51 total bound parameter sets ...  (50, "S4E18: Hezbollah: Israel's Menace or Lebanon's Defender?", 1), (51, 'S4E19: Yemen: In the Shadow of the Imam', 1)]
# 2024-07-19 01:47:46,982 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-19 01:47:46,992 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-19 01:47:47,040 INFO sqlalchemy.engine.Engine INSERT INTO elements (element_id, element_text, segment_id) VALUES (?, ?, ?)
# 2024-07-19 01:47:47,041 INFO sqlalchemy.engine.Engine [generated in 0.01039s] [(7, "Thomas Small Let's get into it. ", 1), (8, "We'll start this series with an event that catapulted the conflicts of the Middle East into the global consciousness: The Twin Tower attacks on September 11th. ", 1), (9, 'Aimen Dean Okay.', 1), (10, "Thomas Small Right. So, we're just starting. ", 1), (11, 'Aimen Dean Yeah. Go ahead.', 1), (12, "Thomas Small Aimen Dean. How do I introduce Aimen Dean? There is literally no one on Planet Earth like Aimen Dean. Saudi-born, but Bahraini nationali ... (904 characters truncated) ... s his former al-Qaeda – the surviving former al-Qaeda jihadists and their followers want to kill him dead for stabbing them in the back. Aimen Dean. ", 1), (13, 'Aimen Dean Well, that was, you know, a rather ominous introduction. Well, Thomas, how am I going to introduce you? Even after years of knowing you—po ... (715 characters truncated) ... e nuances, the… Understand the Bedouin culture?\' You know, if I want to describe Thomas Small in few words, I would say that he is no small at all. ', 1), (14, "Thomas Small Well, here's the thing, Aimen. I met you and I felt weirdly like I had met some kind of spiritual brother.", 1)  ... displaying 10 of 12396 total bound parameter sets ...  (15609, 'There you will find other fans of the show engaging in heated debates, enlightening conversations, and just generally geeking out over Conflicted related topics.', 51), (15610, 'Conflicted is a Message Heard production. This episode was produced and edited by Harry Stott. Sandra Ferrari is our executive producer. Our theme music is by Matt Huxley and Tom Biddle.', 51)]
# 2024-07-19 01:47:47,057 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-19 01:47:47,063 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-19 01:47:47,074 INFO sqlalchemy.engine.Engine INSERT INTO annotations (annotation_id, element_id, code_id) VALUES (?, ?, ?)
# 2024-07-19 01:47:47,074 INFO sqlalchemy.engine.Engine [generated in 0.00471s] [(0, 12, 12), (1, 12, 35), (2, 12, 42), (3, 12, 70), (4, 12, 381), (5, 12, 60), (6, 12, 48), (7, 12, 725)  ... displaying 10 of 5505 total bound parameter sets ...  (5503, 15603, 719), (5504, 15606, 719)]
# 2024-07-19 01:47:47,080 INFO sqlalchemy.engine.Engine COMMIT
# /var/folders/qf/j616b9d53yn77zcpky42s5r40000gn/T/ipykernel_65679/2863780145.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   data: list[dict[Hashable, Any]] = df.to_dict(orient='records') # type: ignore

# %%
# Step 1: Select a random code item
random_code = session.query(Code).order_by(func.random()).first()

if random_code:
    code_id = random_code.code_id
    print("Random Code ID:")
    print(code_id)
    print("Random Code Item:")
    print(random_code)

    # Step 2: Find all annotations associated with the selected code
    annotations = session.query(Annotation).filter(Annotation.code_id == code_id).all()

    if annotations:
        print('----\nRESULTS\n-----')
        for annotation in annotations:
            print("\nAssociated Annotation:")
            print(annotation)

            # Step 3: Retrieve all elements associated with those annotations
            element_id = annotation.element_id
            element = session.query(Element).filter(Element.element_id == element_id).first()

            if element:
                print("\nAssociated Element:")
                print(element)
            else:
                print("No associated elements found.")
            print("\n")
            print("--------------------------------------------------")
            print("\n")
    else:
        print("No associated annotations found.")
else:
    print("No codes found in the database.")
# Out:
# 2024-07-19 01:47:47,087 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-19 01:47:47,089 INFO sqlalchemy.engine.Engine SELECT codes.code_id AS codes_code_id, codes.term AS codes_term, codes.description AS codes_description, codes.type_id AS codes_type_id, codes.reference AS codes_reference, codes.coordinates AS codes_coordinates
# FROM codes ORDER BY random()
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,090 INFO sqlalchemy.engine.Engine [generated in 0.00052s] (1, 0)
# Random Code ID:
# 182
# Random Code Item:
# Code(code_id=182, term=Taliban, description=An Islamic fundamentalist political movement and military organization in Afghanistan currently ruling the country. They were known for their harsh interpretation of Sharia law and were the de facto rulers of Afghanistan from 1996 until 2001, and regained control in August 2021., type_id=3, reference=https://en.wikipedia.org/wiki/Taliban, coordinates=None)
# 2024-07-19 01:47:47,091 INFO sqlalchemy.engine.Engine SELECT annotations.annotation_id AS annotations_annotation_id, annotations.element_id AS annotations_element_id, annotations.code_id AS annotations_code_id
# FROM annotations
# WHERE annotations.code_id = ?
# 2024-07-19 01:47:47,092 INFO sqlalchemy.engine.Engine [generated in 0.00035s] (182,)
# ----
# RESULTS
# -----
#
# Associated Annotation:
# Annotation(annotation_id=308, element_id=190, code_id=182)
# 2024-07-19 01:47:47,094 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,095 INFO sqlalchemy.engine.Engine [generated in 0.00031s] (190, 1, 0)
#
# Associated Element:
# Element(element_id=190, element_text=Aimen Dean I think he wanted the restoration of the caliphate. He believed in eschatology. He believed that he was one of those foretold in the prophecies that would be paving the way for the Mahdi. You know, the Messiah. So, basically 9/11, not only have, you know, eschatology behind it, messianic vision behind it, and, you know, a political vision behind it, and ideological vision behind it, but also what was ultimately the aim and the goal is creative chaos. That chaos that should reign over the entire region to allow the forces of Islamism to take over. Because he saw what happened in Afghanistan after the civil war between the Mujahideen and the collapse of law and order and the raise of the warlords. That chaos was what enabled the Taliban to take over the entirety of Afghanistan except for a small pocket in the north. You know, so, he saw that chaos will make people yearn for law and order. And the only people who can give law and order based on Sharia are who? The Mujahideen. , segment_id=1)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=396, element_id=596, code_id=182)
# 2024-07-19 01:47:47,095 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,096 INFO sqlalchemy.engine.Engine [cached since 0.001445s ago] (596, 1, 0)
#
# Associated Element:
# Element(element_id=596, element_text=Thomas Small The War on Terror has been going on for eighteen years, but many people don't know the story well. 9/11 happens. Osama bin Laden, then safe and sound in Afghanistan, being protected by his Taliban allies, is suddenly met with a ferocious onslaught from the United States and its partners in the international coalition, which pounds the Taliban, topples their government in Kabul, and forces. al-Qaeda, Osama bin Laden's deputy, Ayman al-Zawahiri, and everyone else to leave Afghanistan. Some of them stay in AfPak, the mountainous region of the Afghanistan-Pakistan border. , segment_id=2)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=515, element_id=648, code_id=182)
# 2024-07-19 01:47:47,096 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,097 INFO sqlalchemy.engine.Engine [cached since 0.002397s ago] (648, 1, 0)
#
# Associated Element:
# Element(element_id=648, element_text=Aimen Dean Well, I – I – I recall saying that the structure of the Taliban supported by al-Qaeda would fall within three to six weeks. And they fell within six weeks. But I said, "And after that, the war will start." You see—. , segment_id=2)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=553, element_id=681, code_id=182)
# 2024-07-19 01:47:47,097 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,098 INFO sqlalchemy.engine.Engine [cached since 0.003609s ago] (681, 1, 0)
#
# Associated Element:
# Element(element_id=681, element_text=Aimen Dean You know, at that time, of course, basically, you know, it's useless to tell people. Put "Osama bin Laden," you know, basically, or put "Muhammad Omar," or the "Taliban" or [crosstalk]., segment_id=2)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=671, element_id=742, code_id=182)
# 2024-07-19 01:47:47,098 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,099 INFO sqlalchemy.engine.Engine [cached since 0.004414s ago] (742, 1, 0)
#
# Associated Element:
# Element(element_id=742, element_text=Aimen Dean I was struck by the resilience of their morale and their spirits despite what seemed to be a massive defeat for the al-Qaeda and Taliban apparatus in Afghanistan. , segment_id=2)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=937, element_id=1049, code_id=182)
# 2024-07-19 01:47:47,099 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,099 INFO sqlalchemy.engine.Engine [cached since 0.005138s ago] (1049, 1, 0)
#
# Associated Element:
# Element(element_id=1049, element_text=Aimen Dean …to depose the Taliban. I supported that, because it was right to do. Although maybe it's later execution was not exactly perfect, but at least, you know, the initial campaign was on the right track. And if they just—. If the Americans just persevered just another year or a year and a half, they would have finished al-Qaeda and Taliban for good. , segment_id=3)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=976, element_id=1089, code_id=182)
# 2024-07-19 01:47:47,100 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,100 INFO sqlalchemy.engine.Engine [cached since 0.006028s ago] (1089, 1, 0)
#
# Associated Element:
# Element(element_id=1089, element_text=Aimen Dean You know, unless if someone's threaten you directly. And, you know, for me, I'm one of those people who, again, controversially, you know, supported the war in Afghanistan. You know, I believe basically it was a just cause to remove the Taliban, because they harboured someone who attacked America on a big scale. And, of course, you can't, you know, be, you know, empathetic, pacifist, basically saying, "Oh, no. No. No. Invasion will not going to solve the problem." No, of course, invasion would have solved the problem. Again, if they stayed the course just another year, with immense fire power and with good planning using special forces, they would have finished al-Qaeda. What happened is that al-Qaeda relocated to Iraq. And that's where—call it destiny, fate, whatever, luck—that one of the most psychopathic jihadist happened to take over the reigns of leadership of the jihad cause in Iraq. , segment_id=3)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=1098, element_id=1190, code_id=182)
# 2024-07-19 01:47:47,101 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,101 INFO sqlalchemy.engine.Engine [cached since 0.006896s ago] (1190, 1, 0)
#
# Associated Element:
# Element(element_id=1190, element_text=Aimen Dean Hamas. You know, Al-Shabab. You know, Taliban, even. Boko Haram., segment_id=4)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=1389, element_id=1414, code_id=182)
# 2024-07-19 01:47:47,102 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,102 INFO sqlalchemy.engine.Engine [cached since 0.007937s ago] (1414, 1, 0)
#
# Associated Element:
# Element(element_id=1414, element_text=Of course, why the war went wrong, you know, in Yemen, there are lots of reasons. But the first reason is that the Saudis are, one, not a great military power. It's a medium-sized power. And it's taking on a militia that is four times the size of the Taliban in Afghanistan. And the US with all its might, the UK, France, Germany, and other NATO countries, as well as the Afghan army, they were fighting the Taliban now for seventeen years in Afghanistan. And no are—. We are nowhere near an end. In fact, they fought—., segment_id=4)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=1392, element_id=1415, code_id=182)
# 2024-07-19 01:47:47,103 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,103 INFO sqlalchemy.engine.Engine [cached since 0.009028s ago] (1415, 1, 0)
#
# Associated Element:
# Element(element_id=1415, element_text=Thomas Small And now, we're in negotiations with the Taliban [unintelligible] in a power sharing agreement for the country. , segment_id=4)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=1395, element_id=1416, code_id=182)
# 2024-07-19 01:47:47,104 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,104 INFO sqlalchemy.engine.Engine [cached since 0.009854s ago] (1416, 1, 0)
#
# Associated Element:
# Element(element_id=1416, element_text=Aimen Dean Absolutely. So, in a sense, if the Americans and the entire NATO coalition couldn't do it in Afghanistan, how could the Saudis basically be able to finish the war decisively?, segment_id=4)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=1552, element_id=2358, code_id=182)
# 2024-07-19 01:47:47,105 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,105 INFO sqlalchemy.engine.Engine [cached since 0.0107s ago] (2358, 1, 0)
#
# Associated Element:
# Element(element_id=2358, element_text=Thomas Small Sure. But you might say, if the greatest threat of all is some sort of Taliban-style government rolling across the Middle East, then perhaps you need an authoritarian secularist to crack some skulls and break some eggs to prevent an even worse evil from – from establishing itself., segment_id=5)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=1828, element_id=3081, code_id=182)
# 2024-07-19 01:47:47,106 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,106 INFO sqlalchemy.engine.Engine [cached since 0.01162s ago] (3081, 1, 0)
#
# Associated Element:
# Element(element_id=3081, element_text=Aimen Dean Yes. But a minority. I still basically am a bit sceptical. I would say, basically, a minority can be rehabilitated, especially if they are, as, you know, as I was in the past, basically, and annoyingly inquisitive and a free thinker. You know, this is what needs to happen. You spot them. You see, basically, that there are people who think or themselves, who are, you know, willing to question what they've done. These are the people you should target. Those who stubbornly, stubbornly hold on to the animosity towards every society on earth, that's who you should isolate. I would accept individuals who want to come back if they just go and walk in into the British embassy in Ankara or in Nairobi or in Islamabad and declare, "I'm a walk-in. That's it. I want to renounce the group and everything that stands for." Whether it's al-Qaeda or ISIS or Taliban or al-Shabaab or whatever. If they do that, then that is actually a true willingness to abandon that path. , segment_id=6)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2122, element_id=3850, code_id=182)
# 2024-07-19 01:47:47,107 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,107 INFO sqlalchemy.engine.Engine [cached since 0.01267s ago] (3850, 1, 0)
#
# Associated Element:
# Element(element_id=3850, element_text=AIMEN: Absolutely. And he offered his help, you know, against the Taliban. Which he did actually. You know, the Russian military and intelligence provided, you know significant help to the US and the UK war efforts in Afghanistan., segment_id=9)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2265, element_id=4150, code_id=182)
# 2024-07-19 01:47:47,108 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,108 INFO sqlalchemy.engine.Engine [cached since 0.0135s ago] (4150, 1, 0)
#
# Associated Element:
# Element(element_id=4150, element_text=AIMEN: And Afghanistan, you know, fighting alongside the Taliban., segment_id=10)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2296, element_id=4211, code_id=182)
# 2024-07-19 01:47:47,108 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,108 INFO sqlalchemy.engine.Engine [cached since 0.01421s ago] (4211, 1, 0)
#
# Associated Element:
# Element(element_id=4211, element_text=THOMAS: So, I was personally first introduced to this new reality of a growing China by a friend of mine. His name was Alexandros Petersen. A brilliant young American man who lived in central Asia, lived in China and was studying… He was actually one of the world's experts on the new Silk Road and what it meant for the world. Sadly, the Taliban assassinated, or he was a victim of a Taliban bombing in Kabul where he was teaching at a university and he died., segment_id=10)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2422, element_id=6415, code_id=182)
# 2024-07-19 01:47:47,109 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,109 INFO sqlalchemy.engine.Engine [cached since 0.01499s ago] (6415, 1, 0)
#
# Associated Element:
# Element(element_id=6415, element_text=In our bonus episode, we focused on the story of the Taliban's rise to power in the nineties and took you, the listener, behind the scenes with Aimen's dramatic story of facing an oncoming caravan of Taliban warriors and being unable to fire upon them. We thought it was important to go on a historical deep dive, because, at the time, the news reports were all focused on the present. But that's what Conflicted does best. On the picture of the present, we paint in the background to help you understand the present better., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2433, element_id=6425, code_id=182)
# 2024-07-19 01:47:47,110 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,110 INFO sqlalchemy.engine.Engine [cached since 0.01583s ago] (6425, 1, 0)
#
# Associated Element:
# Element(element_id=6425, element_text=Aimen Dean I thought that the Taliban will be able to withstand the American onslaught for roughly six months, because it's not a Vietnam. I knew that the advanced technology and the experience of the Americans in Iraq in the Gulf War against Saddam Hussein to liberate Kuwait made sure that the Americans basically will not, you know, be bogged down in the sense that they would be able to smash the Taliban's fighting ability as a coherent force., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2434, element_id=6426, code_id=182)
# 2024-07-19 01:47:47,111 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,111 INFO sqlalchemy.engine.Engine [cached since 0.01673s ago] (6426, 1, 0)
#
# Associated Element:
# Element(element_id=6426, element_text=Thomas Small You thought the Taliban would hold out for six months. But in the end, they – they barely survived six weeks. Why is that?, segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2435, element_id=6427, code_id=182)
# 2024-07-19 01:47:47,111 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,112 INFO sqlalchemy.engine.Engine [cached since 0.01739s ago] (6427, 1, 0)
#
# Associated Element:
# Element(element_id=6427, element_text=Aimen Dean You know, many Taliban units who were tribal in their nature, they decided to basically, "Just pack and leave. I'm not going to withstand the B52s dropping, you know, know hundreds of tons of explosive over my head. I can't fight that. So, I'm going to go back to my family." Because, don't forget, the Talibans were not wearing, you know, distinct informs. They all wore civilian clothing. So, they melted into the background, which collapsed the Taliban's ability to run a military campaign to—. It was just the Americans., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2437, element_id=6430, code_id=182)
# 2024-07-19 01:47:47,112 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,113 INFO sqlalchemy.engine.Engine [cached since 0.01834s ago] (6430, 1, 0)
#
# Associated Element:
# Element(element_id=6430, element_text=So, you know, that continuous barrage of massive ordinance falling over Taliban positions, which actually had more psychological effect, you know, than just actual the damage., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2438, element_id=6431, code_id=182)
# 2024-07-19 01:47:47,113 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,113 INFO sqlalchemy.engine.Engine [cached since 0.01912s ago] (6431, 1, 0)
#
# Associated Element:
# Element(element_id=6431, element_text=Thomas Small So, at that time, I mean, here we have this lightning strike invasion of the Taliban fold quite quickly and the coalition has – has clamped the country fast., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2439, element_id=6433, code_id=182)
# 2024-07-19 01:47:47,114 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,114 INFO sqlalchemy.engine.Engine [cached since 0.01985s ago] (6433, 1, 0)
#
# Associated Element:
# Element(element_id=6433, element_text=Aimen Dean From the beginning, you know, the thinking in DC and in 10 Downing Street was the Taliban must go. And, therefore, who will replace them? So, from the beginning, the question of nation building was on the table., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2440, element_id=6437, code_id=182)
# 2024-07-19 01:47:47,115 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,115 INFO sqlalchemy.engine.Engine [cached since 0.02053s ago] (6437, 1, 0)
#
# Associated Element:
# Element(element_id=6437, element_text=Aimen Dean I think three weeks into the war. When you start to see over-reliance of, you know, on warlords who were involved, you know, in gang activities and drugs. So, the over-reliance on these—. Yes, they were opposing forces to the Taliban, but they were criminal classes. I mean, they were, you know, people who the Taliban put away for a good reason. They were terrorising the civilian population before. And so, this Machiavellian execution of the war started to, you know, give me doubts that—. I don't think basically they are serious about nation building., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2442, element_id=6439, code_id=182)
# 2024-07-19 01:47:47,115 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,115 INFO sqlalchemy.engine.Engine [cached since 0.02115s ago] (6439, 1, 0)
#
# Associated Element:
# Element(element_id=6439, element_text=Aimen Dean They could have more or less picked up their allies in a better way and allied themselves more with the tribal leadership and relied on a more tribal consensus building, you know, effort rather than trying to, you know, rely on warlords and people who were involved in the drug trade, you know, prior to the rise of Taliban. However, you know, more or less the biggest doubt that came to my mind that there is going to be a difficulty in this nation building was the rejection of the return of the monarchy to Afghanistan., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2444, element_id=6440, code_id=182)
# 2024-07-19 01:47:47,116 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,116 INFO sqlalchemy.engine.Engine [cached since 0.0217s ago] (6440, 1, 0)
#
# Associated Element:
# Element(element_id=6440, element_text=Thomas Small Yes. That in December of 2001, at the – during the negotiations and bond between the Afghan power players, not including the Taliban, the Afghan party wanted to bring back the king, but the Americans vetoed that. And you – you think that that was a sign that the American nation building project was – was sort of more ideologically slanted than it should have been?, segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2445, element_id=6441, code_id=182)
# 2024-07-19 01:47:47,116 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,117 INFO sqlalchemy.engine.Engine [cached since 0.02234s ago] (6441, 1, 0)
#
# Associated Element:
# Element(element_id=6441, element_text=Aimen Dean Yes. And there is actually another, you know, a mistake, which I highlighted at the time. You know that the Taliban are Deobandis and they listen, you know, a lot to the Deobandi scholars in Pakistan and India., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2447, element_id=6442, code_id=182)
# 2024-07-19 01:47:47,117 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,117 INFO sqlalchemy.engine.Engine [cached since 0.02312s ago] (6442, 1, 0)
#
# Associated Element:
# Element(element_id=6442, element_text=Thomas Small So, long-term listeners will remember that the Deobandi movement, which comes from Northern India during the – during the Raj, during the British rule there, is one of the – one of the biggest ref- – reformist, revivalist political Islamic movements in the world. Because it – because it grew up in the context of throwing out the British. It has a particularly strong anti-Western anti-imperialist edge to it. And the Taliban are – are – are a part of that stream of modern Islamist thought., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2449, element_id=6443, code_id=182)
# 2024-07-19 01:47:47,118 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,118 INFO sqlalchemy.engine.Engine [cached since 0.02385s ago] (6443, 1, 0)
#
# Associated Element:
# Element(element_id=6443, element_text=Aimen Dean Exactly. I suggested, at that time, that there are many moderate pacifist Deobandi scholars, Afghan and Pakistani and Indian who could have been actually courted initially, even if it was just outside of the bomb process in order to, you know, facilitate the—. Not only the—. Well, we don't call it the surrender, but the rehabilitation of the Taliban back into the political fold. So, they can be, you know, placated and, at the same time, not be pushed towards mounting a resistance movement in the future., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2451, element_id=6445, code_id=182)
# 2024-07-19 01:47:47,119 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,119 INFO sqlalchemy.engine.Engine [cached since 0.02463s ago] (6445, 1, 0)
#
# Associated Element:
# Element(element_id=6445, element_text=Thomas Small So, as you say too many warlords had been invited into the process, warlords whom the Afghans had effectively rejected earlier. And this is because the Americans, you know, they'd assumed, if you were against the Taliban, you were good, forgetting that the Taliban had, of course, arisen by – by fighting arseholes., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2454, element_id=6451, code_id=182)
# 2024-07-19 01:47:47,119 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,120 INFO sqlalchemy.engine.Engine [cached since 0.02554s ago] (6451, 1, 0)
#
# Associated Element:
# Element(element_id=6451, element_text=Aimen Dean Turkey, Iran, Egypt. I mean, there is no shortage of big armies in the Muslim world. I mean, Indonesia, Malaysia, Pakistan, Bangladesh, as well as Iran, Turkey, Saudi Arabia, Egypt, all of these countries, basically, among them, they have millions of men, you know, men in terms of manpower. They could have spared the a hundred thousand troops easy in order to facilitate that kind of, you know, revivalist, Afghan political tradition of the loya jirga. Like, you know, I mean, of this kind of rule by consensus. It could have happened. But no one reached out to them, because, somehow, the Taliban basically were viewed as the absolute villains. Everyone forget that Afghan, you know, society and Afghan history is full of villains. It's just basically some of them are better than others., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2457, element_id=6453, code_id=182)
# 2024-07-19 01:47:47,120 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,120 INFO sqlalchemy.engine.Engine [cached since 0.02626s ago] (6453, 1, 0)
#
# Associated Element:
# Element(element_id=6453, element_text=Aimen Dean I think it's just the inability to see further than a four-year election cycle. It's a question of "Okay. We want to show the American public that we took revenge." And, you know, you – you could have taken the revenge right away, like—. And I mean, just bomb the hell out of them. But the question here is what will replace the Taliban afterwards to make sure that the Taliban do not return. Because, guess what, twenty years later, the Taliban returned., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2458, element_id=6454, code_id=182)
# 2024-07-19 01:47:47,121 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,121 INFO sqlalchemy.engine.Engine [cached since 0.02697s ago] (6454, 1, 0)
#
# Associated Element:
# Element(element_id=6454, element_text=Thomas Small Okay. So, to—. Before we get to the now, we can do a quick summary of what happened after the invasion. So, between 2001 and 2008, the peace process did – did sort of move ahead, the bond agreement was signed, elections were held, Hamid Karzai became president. And you know, it was fairly calm at first. Then, as you told us in the last episode, the US got distracted by Iraq and the Al Qaeda terrorists leader there, Zarqawi, rose, began sending money to the Taliban where they were held out in the – in the Af-Pak border. And then, they started launching terrorist attacks inside Afghanistan, again creating the instability that became endemic there., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2465, element_id=6459, code_id=182)
# 2024-07-19 01:47:47,122 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,122 INFO sqlalchemy.engine.Engine [cached since 0.02798s ago] (6459, 1, 0)
#
# Associated Element:
# Element(element_id=6459, element_text=Thomas Small Well, that makes sense to me, Aimen. More troops, more – more, you know, more fists punching the Taliban in the face., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2466, element_id=6460, code_id=182)
# 2024-07-19 01:47:47,123 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,123 INFO sqlalchemy.engine.Engine [cached since 0.02901s ago] (6460, 1, 0)
#
# Associated Element:
# Element(element_id=6460, element_text=Aimen Dean Yeah. But, again, we come back to comparing oranges and apples here. We come back to comparing Iraq and Afghanistan. You can't compare a rock, which is an open desert, to Afghanistan, which is a mountain society. You know, Iraq, which has a decades of central government with Afghanistan, which has decades of rural, you know, population. You can't compare the two at all. And, therefore, you know, the idea that the troops there will actually serve as a catalyst for the Taliban to, you know, capitulate, it was the opposite. They increased their ranks. They increased their number. More recruits joined them, because, you know, it's like introducing more virus into a body that will, you know, create more antibodies. Obama would have actually done better if he spent the money on the infrastructure of the country than actually sending more troops., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2474, element_id=6484, code_id=182)
# 2024-07-19 01:47:47,124 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,124 INFO sqlalchemy.engine.Engine [cached since 0.03014s ago] (6484, 1, 0)
#
# Associated Element:
# Element(element_id=6484, element_text=Aimen Dean Well, you know, when you are, you know, fighting a war, you don't rock the boat. I mean, you're already fighting a war and you know, basically, that, you know, this money is going here on there, and it is important that this money keeps flowing because it is feeding, you know, the Black Ops, it is feeding the irregular rendition sites, it is feeding, you know, the, operations that you need to be done in order to win the war against the Taliban in a dirty way, which your military is restrained from doing. That is exactly, you know, the issue. Bribing certain officials. Bribing tribal leaders. Paying ransom money, you know, to certain local commanders in order – you know, from the Afghan, you know, society in order to facilitate the American intelligence gathering, and, you know, so on. So—. And so, you know, that's why in any war, you will find that dirty money is part of it. But in Afghanistan, the dirty money almost – almost matched to the legitimate money., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2478, element_id=6487, code_id=182)
# 2024-07-19 01:47:47,125 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,125 INFO sqlalchemy.engine.Engine [cached since 0.03108s ago] (6487, 1, 0)
#
# Associated Element:
# Element(element_id=6487, element_text=Thomas Small And when we talk about ISIS in Afghanistan, are we talking about the whole country? Are they everywhere? And I mean, I would've thought, you know, ISIS and the Taliban would get along, you know. I mean, why – why – why are ISIS there, fighting the Taliban, and ISIS—. I mean, it seems crazy. Aren't ISIS and Taliban equally bad guys, you know? Aren't they both terrorists?, segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2481, element_id=6490, code_id=182)
# 2024-07-19 01:47:47,126 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,126 INFO sqlalchemy.engine.Engine [cached since 0.03171s ago] (6490, 1, 0)
#
# Associated Element:
# Element(element_id=6490, element_text=And – and – and by Salafist, we mentioned earlier how the Taliban are attached to the Deobandi movement. Salafism is a different movement. It comes from the Arab part of the Middle East. It is associated with the Muslim Brotherhood, with characters like Sayyid Qutb. It comes with – with a fusion with Saudi-inflicted Wahhabism., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2495, element_id=6499, code_id=182)
# 2024-07-19 01:47:47,126 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,127 INFO sqlalchemy.engine.Engine [cached since 0.0324s ago] (6499, 1, 0)
#
# Associated Element:
# Element(element_id=6499, element_text=Aimen Dean I believe they were just a disruptive force. I mean, their ultimate aim is just the disruption and to present themselves, hopefully, as the alternative to the Taliban, to those Taliban units who believed that the Taliban were not, you know, vigorous enough in their pursuit of an American withdrawal from Afghanistan. And they succeeded in attracting a few hundred disaffected Taliban fighters. But that's it., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2499, element_id=6501, code_id=182)
# 2024-07-19 01:47:47,127 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,127 INFO sqlalchemy.engine.Engine [cached since 0.03295s ago] (6501, 1, 0)
#
# Associated Element:
# Element(element_id=6501, element_text=Thomas Small I see. So, the Obama years are coming to a close now. We have this situation where ISIS is – is – is on the rampage in Afghanistan. The Taliban are well and truly back, causing problems. Corruption, heretofore, unimagined, is endemic both within the Afghan and the American security apparatus. And then, we come to Donald Trump. So, Donald Trump had risen to power by attaching himself to, really, the isolationist wing of the Republican party, the old right of the Republican party who were not interested in policing the world. They rejected the neo-conservative movement. He had no interest in nation building and was determined to get out of Afghanistan. So, as Donald Trump enters the scene, Aimen, were you encouraged?, segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2503, element_id=6504, code_id=182)
# 2024-07-19 01:47:47,128 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,128 INFO sqlalchemy.engine.Engine [cached since 0.03364s ago] (6504, 1, 0)
#
# Associated Element:
# Element(element_id=6504, element_text=Aimen Dean Say whatever you want to say about Donald Trump—and there are, you know—. You know, we could be spending hours talking about his faults. But he recognised, in Afghanistan, not only a lost cause, but he recognised what Afghanistan really was: a money-making scheme for corrupt, you know, Afghan officials and American officials and American military, generals. And, therefore—. []x contractors. Therefore, he decided, "You know what? Let's talk to the Taliban. Let's continue the – those tentative inner first steps that Obama took in order to talk to the Taliban in Doha, in Qatar, and let – let the Qataris be the mediators." And this is, I think, where it started., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2507, element_id=6505, code_id=182)
# 2024-07-19 01:47:47,128 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,129 INFO sqlalchemy.engine.Engine [cached since 0.03435s ago] (6505, 1, 0)
#
# Associated Element:
# Element(element_id=6505, element_text=Thomas Small To move away from the American perspective and – and start walking in the Afghan shoes at the moment, I mean, it's obvious now that Afghans themselves agreed with you at the time and they knew that their hold on power was shaky and that they needed to negotiate with the Taliban. I mean, Hamid Karzai, then the president, he wanted negotiations to start in 2007, but the Bush administration refused. So, Karzai knew, as early as 2007, when the Taliban were then well and truly coming back. "We must negotiate with these players." But Bush said no. There were negotiations with other resistance militias, including your old friend Hekmatyar's group, Hezb-e-Islami., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2508, element_id=6507, code_id=182)
# 2024-07-19 01:47:47,129 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,130 INFO sqlalchemy.engine.Engine [cached since 0.03531s ago] (6507, 1, 0)
#
# Associated Element:
# Element(element_id=6507, element_text=Thomas Small And they did sign a peace treaty with the Afghan government in 2016. So, on the ground in Afghanistan, the Afghan government, to the extent that it was sovereign, was trying to cobble together some sort of peaceful arrangement with these other actors. Now, in February 2018, Donald Trump is president and Karzai's successor as president of Afghanistan, Ashraf Ghani, publicly called for peace talks with the Taliban. Now, presumably, he would have discussed this move with the Americans, and Trump said, "Okay. Go for it." And then, a new – a resurgent peace movement began again in Afghanistan. And the people, they were worn out. They wanted an end to all the fighting. And then, there was a big conference in Tashkent, in Uzbekistan, where twenty countries, including the US, lent their support to President Ghani's call for peace talks. So, how is it that a few months later, in July 2018, the Taliban ended up talking peace with the Americans in Doha, in Qatar? Trump had asked the generals, "Look, how do we end this shit show there in Doha?" Why Doha?, segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2512, element_id=6508, code_id=182)
# 2024-07-19 01:47:47,130 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,131 INFO sqlalchemy.engine.Engine [cached since 0.03638s ago] (6508, 1, 0)
#
# Associated Element:
# Element(element_id=6508, element_text=Aimen Dean First of all, the Taliban, from the beginning, did not trust the government of Ashraf Ghani. So, the end of the day, you know, I want to talk with the paymasters. I mean, the Taliban knew exactly that. Abdul Rashid Dostum, Mohammad Fahim, Ismail Khan, all of the leaders, Abdullah Abdullah, all of the leaders of the Afghan government and their factions, you know, ethnic or otherwise, depend on American patronage. So, why am I going to waste my time talking to them? Because they will be going back to their paymasters, the American. They will be asking their opinion. They will come back again. And I don't trust if they are going to tell the Americans what we want to tell the Americans. And I can't trust that they will tell us what the Americans really wanted to tell us., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2513, element_id=6509, code_id=182)
# 2024-07-19 01:47:47,131 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,132 INFO sqlalchemy.engine.Engine [cached since 0.03756s ago] (6509, 1, 0)
#
# Associated Element:
# ...
# Element(element_id=6558, element_text=Aimen Dean All what Russia wants is for the Taliban to control the IMU, you know, which is the Islamic Movement of Uzbekistan, the Tajik jihadists, and others from not launching cross-border attacks into these countries or trying to destabilise these countries. These countries are considered to be satellite countries as far as Moscow is concerned., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2573, element_id=6560, code_id=182)
# 2024-07-19 01:47:47,157 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,157 INFO sqlalchemy.engine.Engine [cached since 0.063s ago] (6560, 1, 0)
#
# Associated Element:
# Element(element_id=6560, element_text=Aimen Dean Exactly. They are considered to be the security buffer, you know, know as far as Russia is concerned. And so, the – the Russians are offering a infrastructure projects, you know, maintaining the dams in Sarawbi and in Daruntah, and some hydroelectric power projects, you know, in the country in return for a goodwill from the Taliban. And the Taliban basically are, you know, feeling that, well, you know, why not? Like, and I mean, if the, you know—. And this is why the Taliban are actually, you know, playing some game here. They are making, you know, all these groups a little bit visible on the border, you know. They're making the IMU visible. They are making the jihadi Tajiks visible in Badakshan. Also, in Badakshan—., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2577, element_id=6564, code_id=182)
# 2024-07-19 01:47:47,158 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,158 INFO sqlalchemy.engine.Engine [cached since 0.06362s ago] (6564, 1, 0)
#
# Associated Element:
# Element(element_id=6564, element_text=Aimen Dean Exactly. So, the Taliban are, you know, savvy, you know, political operators. They are not your average tower heads. Like, you know, they are more smarter than you would give them credit for. And they are using this leverage on both China and Russia to gain as much concessions as possible., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2579, element_id=6566, code_id=182)
# 2024-07-19 01:47:47,158 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,158 INFO sqlalchemy.engine.Engine [cached since 0.06423s ago] (6566, 1, 0)
#
# Associated Element:
# Element(element_id=6566, element_text=Aimen Dean Not only that. But how many other, you know, multinational companies, you know, are going to be crazy enough to go out and operate in Afghanistan? Most of the mining companies are either from Australia, Canada, and America and Europe. And none of these have the risk appetite to go and actually operate in a very dangerous environment like Afghanistan. So, you really only have the Chinese and, to some extent, the South Koreans and the Japanese and the Malaysians, you know, who – and the Turks who are more than willing and happy to come and operate. So, these are the countries that are already courting the Taliban over the question of the minerals and the minerals rights., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2582, element_id=6570, code_id=182)
# 2024-07-19 01:47:47,159 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,159 INFO sqlalchemy.engine.Engine [cached since 0.06483s ago] (6570, 1, 0)
#
# Associated Element:
# Element(element_id=6570, element_text=Aimen Dean I think the Americans went wrong when they actually decided that, instead of waging a campaign to rebuild Afghanistan in terms of infrastructure, they decided to actually just fund projects that were designed to say to the Taliban "in your face." They waged the cultural war on Taliban values, forgetting that some of these values are also entrenched Afghan values. So, trying to teach modern arts to Afghan people and trying to talk to them about, you know, modern liberal, you know, ideals as – and spend money on these programs that were supposed to be allocated to infrastructure and for things, basically, that will actually bring them benefit, that alienated more Afghan and actually emboldened the Taliban., segment_id=13)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2746, element_id=7139, code_id=182)
# 2024-07-19 01:47:47,160 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,160 INFO sqlalchemy.engine.Engine [cached since 0.06551s ago] (7139, 1, 0)
#
# Associated Element:
# Element(element_id=7139, element_text=Aimen Dean Well, if you talk to those who were Russia desk analysts and officers in, you know, whether the British intelligence or the German intelligence or other services, they will tell you that there is no need to antagonise Russia this way. I mean, after all, the spectre of al-Qaeda, the spectre of the Taliban was still there. We were still fighting a war against terrorism. There are many Chechens who are using the Pankisi Gorge, then later would infiltrate into places like Afghanistan to kill Americans, they would infiltrate into places like Iraq to kill Americans, and they will infiltrate into Syria later. , segment_id=16)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=3189, element_id=8479, code_id=182)
# 2024-07-19 01:47:47,160 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,161 INFO sqlalchemy.engine.Engine [cached since 0.06635s ago] (8479, 1, 0)
#
# Associated Element:
# Element(element_id=8479, element_text=Aimen Dean Many listeners, you know, will be thinking right now that, "Oh, we have a war on Ukraine. We have a war, you know, with the Taliban. You know, took over Afghanistan. We have, you know, crisis here, crisis there.", segment_id=22)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=3311, element_id=9072, code_id=182)
# 2024-07-19 01:47:47,161 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,161 INFO sqlalchemy.engine.Engine [cached since 0.06727s ago] (9072, 1, 0)
#
# Associated Element:
# Element(element_id=9072, element_text=Aimen Dean At the time, I was looking into groups like Lashkar-e-Taiba, Jaish-e-Mohammed. I was looking into their relationship with al-Qaeda. The training camps of al-Qaeda set up for them there in conjunction with the Pakistani military. The Pakistani ISI. And also, at the same time, understanding their financial and cultural and ideological relationship with al-Qaeda and the Taliban and the relationship between all of these groups., segment_id=24)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=3722, element_id=10772, code_id=182)
# 2024-07-19 01:47:47,162 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,163 INFO sqlalchemy.engine.Engine [cached since 0.0683s ago] (10772, 1, 0)
#
# Associated Element:
# Element(element_id=10772, element_text=And then before series three, we had a bonus episode, which talked about the ancient history of Afghanistan. So, we've already covered that, all the way up to the rise of the Taliban in the late nineties., segment_id=30)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=3826, element_id=10891, code_id=182)
# 2024-07-19 01:47:47,163 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,164 INFO sqlalchemy.engine.Engine [cached since 0.06959s ago] (10891, 1, 0)
#
# Associated Element:
# Element(element_id=10891, element_text=Thomas:    Well, the Saqqawists as I say, they were brigands, they were basically incompetent. They quickly alienated everyone. They remind me in their incompetence, a little bit of the Taliban in the late nineties., segment_id=30)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=4150, element_id=11860, code_id=182)
# 2024-07-19 01:47:47,164 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,165 INFO sqlalchemy.engine.Engine [cached since 0.07033s ago] (11860, 1, 0)
#
# Associated Element:
# Element(element_id=11860, element_text=Thomas: When you think of Pakistan fracturing and allowing those extremist tendencies to really rise to the top, all the old players come up: Al-Qaeda to the Taliban there on the border, ISIS, all the big groups. But we're going to stop right there before we get into those groups themselves. Let's go for a quick break., segment_id=33)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=4427, element_id=12747, code_id=182)
# 2024-07-19 01:47:47,165 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,165 INFO sqlalchemy.engine.Engine [cached since 0.07099s ago] (12747, 1, 0)
#
# Associated Element:
# Element(element_id=12747, element_text=But the reality wasn't true. In fact, the Taliban were Sufis. I remember we were walking on one of the streets of Jalalabad, and from a building on the second floor from the windows, we can see, and we can hear a Sufi Haḍra like basically when they have the drums and the dancing, and we see the men of the Taliban with their turbans, and they were doing that Sufi dance in a circle, and we were hearing the drums., segment_id=38)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=4433, element_id=12749, code_id=182)
# 2024-07-19 01:47:47,166 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,166 INFO sqlalchemy.engine.Engine [cached since 0.07209s ago] (12749, 1, 0)
#
# Associated Element:
# Element(element_id=12749, element_text=They were so against it. However, all I see is that the vast majority of Jihad activity and Jihadism was actually undertaken by Sufis. In Afghanistan, it was the Taliban, and the other Mujahideen parties., segment_id=38)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=4566, element_id=13181, code_id=182)
# 2024-07-19 01:47:47,167 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,167 INFO sqlalchemy.engine.Engine [cached since 0.07287s ago] (13181, 1, 0)
#
# Associated Element:
# Element(element_id=13181, element_text=Aimen: To this day, this dynamic of having the political leadership on one side and the religious leadership on the other side, coexisting and working together for one mission still exists to this day among jihadi groups, whether it is Al-Qaeda or ISIS or any of the other, in even Hamas and the Taliban., segment_id=40)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=4752, element_id=13670, code_id=182)
# 2024-07-19 01:47:47,168 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,168 INFO sqlalchemy.engine.Engine [cached since 0.07366s ago] (13670, 1, 0)
#
# Associated Element:
# Element(element_id=13670, element_text=Aimen: Not only the Salafits, but many other groups and all of those armed groups Taliban, Hamas, Al-Qaeda, Al-Shabaab in Somalia. Not to mention even the Islamic Revolution in Iran. I mean even Ayatollah Khomeini translated and his brother Mohammed translated Milestones into Farsi because it is a ready-made constitution for any Islamist movement that want to take over a society and turn it into an Islamic state., segment_id=42)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=5210, element_id=14833, code_id=182)
# 2024-07-19 01:47:47,168 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,169 INFO sqlalchemy.engine.Engine [cached since 0.07441s ago] (14833, 1, 0)
#
# Associated Element:
# Element(element_id=14833, element_text=So, Saudi Arabia, through many geopolitical moves made it favourable for them to have the Taliban in Afghanistan. And through a lot of engineering and political machinations, they were able to oust Imran Khan, the prime minister of Pakistan, or the former prime minister of Pakistan now, who was more pro-Iranian., segment_id=48)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=5212, element_id=14834, code_id=182)
# 2024-07-19 01:47:47,169 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-19 01:47:47,169 INFO sqlalchemy.engine.Engine [cached since 0.07524s ago] (14834, 1, 0)
#
# Associated Element:
# Element(element_id=14834, element_text=And they managed to get a pro-Saudi, anti-Iranian government, and even more pro-Saudi and anti-Iranian head of the military, General Asim Munir. So, they are now pointing two guns at Iran’s back from the East, which is Pakistan, and Taliban in Afghanistan., segment_id=48)
#
#
# --------------------------------------------------
