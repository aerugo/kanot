# %% [markdown]
# # Import data from Conflicted Glossary

# %%
import pandas as pd

# Load the CSV files into DataFrames
codes_df = pd.read_csv('../_temp/glossary.csv')  # type: ignore
elements_df = pd.read_csv('../_temp/transcripts.csv')  # type: ignore

# Rename columns according to the provided mapping
codes_df = codes_df.rename(columns={
    'Glossary ID': 'code_id',
    'Term': 'term',
    'Description': 'description',
    'Type': 'type',
    'Read more': 'reference',
    'Lat/Long': 'coordinates'
})

elements_df = elements_df.rename(columns={
    'Text ID': 'element_id',
    'Text': 'element_text',
    'Episode ID': 'segment_id',
    'Episode': 'segment_title',
    'Glossary IDs': 'code_ids'
})
# drop the columns that are not element_id, element_text, segment_id, segment_title, code_ids
elements_df = elements_df[['element_id', 'element_text', 'segment_id', 'segment_title', 'code_ids']]

elements_df['code_ids'] = elements_df['code_ids'].fillna('') # type: ignore

# remove any rows in the elements_df where the element_text is empty
elements_df = elements_df[elements_df['element_text'].notnull()]

# create a dataframe with all unique segment_id and segment_title
segment_df = elements_df[['segment_id', 'segment_title']].drop_duplicates()

# create a dataframe series_df with autoincrementing column series_id and series_title and add one row with series_title = 'Conflicted Podcast'
series_df = pd.DataFrame({'series_id': [1], 'series_title': ['Conflicted Podcast']})

# add a column series_id to the segment_df dataframe and set the value to 1 for all rows
segment_df['series_id'] = 1

# create a dataframe with all unique glossary type
code_type_df = codes_df[['type']].drop_duplicates()
# rename the column to type_name
code_type_df = code_type_df.rename(columns={'type': 'type_name'})
# create an incrementing type_id column
code_type_df['type_id'] = range(1, len(code_type_df) + 1)

# Create a column type_id in the codes_df dataframe and map the type_name to the type_id
# Merge the code_type_df with the codes_df on type = type_name
codes_df = codes_df.merge(code_type_df, left_on='type', right_on='type_name', how='left') # type: ignore
codes_df = codes_df.rename(columns={'type_name': 'type_id'})
codes_df = codes_df[['code_id', 'term', 'description', 'type_id', 'reference', 'coordinates']]

# %%
# create a dataframe project_df with autoincrementing column project_id and project_title and projcet_description and add one row with project_title = 'Conflicted Glossary' and project_description = 'Glossary for the Conflicted Podcast'
project_df = pd.DataFrame({'project_id': [1], 'project_title': ['Conflicted Glossary'], 'project_description': ['Glossary for the Conflicted Podcast']})

# Add a column project_id to the codes_df dataframe and set the value to 1 for all rows
codes_df['project_id'] = 1

# Add a column project_id to the code_type_df dataframe and set the value to 1 for all rows
code_type_df['project_id'] = 1

# Add a column project_id to the elements_df dataframe and set the value to 1 for all rows
elements_df['project_id'] = 1

# Add a column project_id to the segment_df dataframe and set the value to 1 for all rows
segment_df['project_id'] = 1

# Add a column project_id to the series_df dataframe and set the value to 1 for all rows
series_df['project_id'] = 1

# %%
# Create a new DataFrame annotations_df with columns element_id, code_id
annotations_df = pd.DataFrame(columns=['element_id', 'code_id'])

# Iterate over each row in elements_df and add rows to annotations_df
rows_to_add = []
for index, row in elements_df.iterrows():
    element_id = row['element_id']
    code_ids = row['code_ids'].split(';')
    for code_id in code_ids if code_ids != [''] else []:
        code_id = int(code_id)
        rows_to_add.append({'element_id': element_id, 'code_id': code_id})

elements_df.drop(columns=['code_ids', 'segment_title'], inplace=True) # type: ignore

# Convert list of rows to DataFrame and concatenate
annotations_df = pd.concat([annotations_df, pd.DataFrame(rows_to_add)], ignore_index=True)

# Convert code_id to int
annotations_df['code_id'] = annotations_df['code_id'].astype(int)

# Add a column annotation_id to annotations_df
annotations_df['annotation_id'] = annotations_df.index

# Add a column project_id to the annotations_df dataframe and set the value to 1 for all rows
annotations_df['project_id'] = 1

# %% [markdown]
# # Define Database

# %%
from kanot.db.schema import create_database, drop_database, Project, CodeType, Code, Series, Segment, Element, Annotation
from sqlalchemy import create_engine, Engine
from sqlalchemy.orm import sessionmaker

# Create a connection to the SQLite database
engine: Engine = create_engine('sqlite:///../local_database.db', echo=True)
MySession = sessionmaker(bind=engine)
session = MySession()

drop = True
if drop:
    # Drop all the tables in the database
    drop_database(engine)

# Create the tables in the database
create_database(engine)
# Out:
# 2024-07-26 03:07:01,032 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-26 03:07:01,033 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("projects")
# 2024-07-26 03:07:01,033 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-26 03:07:01,034 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("code_types")
# 2024-07-26 03:07:01,034 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-26 03:07:01,034 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("codes")
# 2024-07-26 03:07:01,034 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-26 03:07:01,035 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("series")
# 2024-07-26 03:07:01,035 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-26 03:07:01,035 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("segments")
# 2024-07-26 03:07:01,036 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-26 03:07:01,036 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("elements")
# 2024-07-26 03:07:01,036 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-26 03:07:01,037 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("annotations")
# 2024-07-26 03:07:01,037 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-26 03:07:01,037 INFO sqlalchemy.engine.Engine
# DROP TABLE annotations
# 2024-07-26 03:07:01,038 INFO sqlalchemy.engine.Engine [no key 0.00020s] ()
# 2024-07-26 03:07:01,039 INFO sqlalchemy.engine.Engine
# DROP TABLE elements
# 2024-07-26 03:07:01,039 INFO sqlalchemy.engine.Engine [no key 0.00026s] ()
# 2024-07-26 03:07:01,042 INFO sqlalchemy.engine.Engine
# DROP TABLE segments
# 2024-07-26 03:07:01,042 INFO sqlalchemy.engine.Engine [no key 0.00028s] ()
# 2024-07-26 03:07:01,043 INFO sqlalchemy.engine.Engine
# DROP TABLE codes
# 2024-07-26 03:07:01,043 INFO sqlalchemy.engine.Engine [no key 0.00021s] ()
# 2024-07-26 03:07:01,044 INFO sqlalchemy.engine.Engine
# DROP TABLE series
# 2024-07-26 03:07:01,044 INFO sqlalchemy.engine.Engine [no key 0.00022s] ()
# 2024-07-26 03:07:01,045 INFO sqlalchemy.engine.Engine
# DROP TABLE code_types
# 2024-07-26 03:07:01,045 INFO sqlalchemy.engine.Engine [no key 0.00025s] ()
# 2024-07-26 03:07:01,046 INFO sqlalchemy.engine.Engine
# DROP TABLE projects
# 2024-07-26 03:07:01,046 INFO sqlalchemy.engine.Engine [no key 0.00016s] ()
# 2024-07-26 03:07:01,047 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-26 03:07:01,047 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-26 03:07:01,048 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("projects")
# 2024-07-26 03:07:01,048 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-26 03:07:01,048 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("projects")
# 2024-07-26 03:07:01,049 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-26 03:07:01,049 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("code_types")
# 2024-07-26 03:07:01,049 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-26 03:07:01,050 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("code_types")
# 2024-07-26 03:07:01,050 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-26 03:07:01,050 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("codes")
# 2024-07-26 03:07:01,050 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-26 03:07:01,051 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("codes")
# 2024-07-26 03:07:01,051 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-26 03:07:01,051 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("series")
# 2024-07-26 03:07:01,051 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-26 03:07:01,051 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("series")
# 2024-07-26 03:07:01,052 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-26 03:07:01,052 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("segments")
# 2024-07-26 03:07:01,052 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-26 03:07:01,052 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("segments")
# 2024-07-26 03:07:01,053 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-26 03:07:01,053 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("elements")
# 2024-07-26 03:07:01,053 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-26 03:07:01,053 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("elements")
# 2024-07-26 03:07:01,054 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-26 03:07:01,054 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("annotations")
# 2024-07-26 03:07:01,054 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-26 03:07:01,054 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("annotations")
# 2024-07-26 03:07:01,054 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-07-26 03:07:01,055 INFO sqlalchemy.engine.Engine
# CREATE TABLE projects (
# 	project_id INTEGER NOT NULL,
# 	project_title TEXT NOT NULL,
# 	project_description TEXT,
# 	PRIMARY KEY (project_id)
# )
#
#
# 2024-07-26 03:07:01,055 INFO sqlalchemy.engine.Engine [no key 0.00028s] ()
# 2024-07-26 03:07:01,057 INFO sqlalchemy.engine.Engine
# CREATE TABLE code_types (
# 	type_id INTEGER NOT NULL,
# 	type_name TEXT NOT NULL,
# 	project_id INTEGER,
# 	PRIMARY KEY (type_id),
# 	CONSTRAINT _type_name_project_uc UNIQUE (type_name, project_id),
# 	FOREIGN KEY(project_id) REFERENCES projects (project_id)
# )
#
#
# 2024-07-26 03:07:01,057 INFO sqlalchemy.engine.Engine [no key 0.00022s] ()
# 2024-07-26 03:07:01,058 INFO sqlalchemy.engine.Engine
# CREATE TABLE series (
# 	series_id INTEGER NOT NULL,
# 	series_title TEXT NOT NULL,
# 	project_id INTEGER,
# 	PRIMARY KEY (series_id),
# 	FOREIGN KEY(project_id) REFERENCES projects (project_id)
# )
#
#
# 2024-07-26 03:07:01,058 INFO sqlalchemy.engine.Engine [no key 0.00021s] ()
# 2024-07-26 03:07:01,059 INFO sqlalchemy.engine.Engine
# CREATE TABLE codes (
# 	code_id INTEGER NOT NULL,
# 	term TEXT NOT NULL,
# 	description TEXT,
# 	type_id INTEGER,
# 	reference TEXT,
# 	coordinates TEXT,
# 	project_id INTEGER,
# 	PRIMARY KEY (code_id),
# 	CONSTRAINT _term_project_uc UNIQUE (term, project_id),
# 	FOREIGN KEY(type_id) REFERENCES code_types (type_id),
# 	FOREIGN KEY(project_id) REFERENCES projects (project_id)
# )
#
#
# 2024-07-26 03:07:01,059 INFO sqlalchemy.engine.Engine [no key 0.00025s] ()
# 2024-07-26 03:07:01,060 INFO sqlalchemy.engine.Engine
# CREATE TABLE segments (
# 	segment_id INTEGER NOT NULL,
# 	segment_title TEXT NOT NULL,
# 	series_id INTEGER,
# 	project_id INTEGER,
# 	PRIMARY KEY (segment_id),
# 	UNIQUE (segment_title),
# 	FOREIGN KEY(series_id) REFERENCES series (series_id),
# 	FOREIGN KEY(project_id) REFERENCES projects (project_id)
# )
#
#
# 2024-07-26 03:07:01,060 INFO sqlalchemy.engine.Engine [no key 0.00024s] ()
# 2024-07-26 03:07:01,061 INFO sqlalchemy.engine.Engine
# CREATE TABLE elements (
# 	element_id INTEGER NOT NULL,
# 	element_text TEXT NOT NULL,
# 	segment_id INTEGER,
# 	project_id INTEGER,
# 	PRIMARY KEY (element_id),
# 	FOREIGN KEY(segment_id) REFERENCES segments (segment_id),
# 	FOREIGN KEY(project_id) REFERENCES projects (project_id)
# )
#
#
# 2024-07-26 03:07:01,061 INFO sqlalchemy.engine.Engine [no key 0.00015s] ()
# 2024-07-26 03:07:01,062 INFO sqlalchemy.engine.Engine
# CREATE TABLE annotations (
# 	annotation_id INTEGER NOT NULL,
# 	element_id INTEGER,
# 	code_id INTEGER,
# 	project_id INTEGER,
# 	PRIMARY KEY (annotation_id),
# 	CONSTRAINT _element_code_uc UNIQUE (element_id, code_id),
# 	FOREIGN KEY(element_id) REFERENCES elements (element_id),
# 	FOREIGN KEY(code_id) REFERENCES codes (code_id),
# 	FOREIGN KEY(project_id) REFERENCES projects (project_id)
# )
#
#
# 2024-07-26 03:07:01,062 INFO sqlalchemy.engine.Engine [no key 0.00025s] ()
# 2024-07-26 03:07:01,063 INFO sqlalchemy.engine.Engine COMMIT

# %%
from sqlalchemy import func
from sqlalchemy.orm import Session
from sqlalchemy.ext.declarative import DeclarativeMeta
from sqlalchemy.exc import IntegrityError
from typing import Any, Hashable

# Define a function to insert data from a DataFrame
def insert_data(df: pd.DataFrame, model: DeclarativeMeta, session: Session) -> None:
    data: list[dict[Hashable, Any]] = df.to_dict(orient='records') # type: ignore
    
    try:
        session.bulk_insert_mappings(model, data) # type: ignore
        session.commit()
    except IntegrityError as e:
        print(f"Unique constraint violation: {e}")
        session.rollback()

# Insert data into the projects table
insert_data(project_df, Project, session)

# Insert data into the code_types table
insert_data(code_type_df, CodeType, session)

# Insert data into the codes table
insert_data(codes_df, Code, session)

# Insert data into the series table
insert_data(series_df, Series, session)

# Insert data into the segments table
insert_data(segment_df, Segment, session)

# Insert data into the elements table
insert_data(elements_df, Element, session)

# Insert data into the annotations table
insert_data(annotations_df, Annotation, session)

# Close the session
session.close()
# Out:
# 2024-07-26 03:07:01,084 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-26 03:07:01,085 INFO sqlalchemy.engine.Engine INSERT INTO projects (project_id, project_title, project_description) VALUES (?, ?, ?)
# 2024-07-26 03:07:01,086 INFO sqlalchemy.engine.Engine [generated in 0.00033s] (1, 'Conflicted Glossary', 'Glossary for the Conflicted Podcast')
# 2024-07-26 03:07:01,086 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-26 03:07:01,088 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-26 03:07:01,088 INFO sqlalchemy.engine.Engine INSERT INTO code_types (type_id, type_name, project_id) VALUES (?, ?, ?)
# 2024-07-26 03:07:01,089 INFO sqlalchemy.engine.Engine [generated in 0.00041s] [(1, 'Person', 1), (2, 'Events and Periods', 1), (3, 'Group', 1), (4, 'Concept: Cultural and Societal', 1), (5, 'Geography', 1), (6, 'Concept: Political and Social', 1), (7, 'Concept: Economics and Infrastructure', 1), (8, 'Concept: Terrorism and Security', 1)  ... displaying 10 of 16 total bound parameter sets ...  (15, 'Education and Institutions', 1), (16, 'Concept: Legal', 1)]
# 2024-07-26 03:07:01,090 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-26 03:07:01,092 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-26 03:07:01,094 INFO sqlalchemy.engine.Engine INSERT INTO codes (code_id, term, description, type_id, reference, coordinates, project_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2024-07-26 03:07:01,095 INFO sqlalchemy.engine.Engine [generated in 0.00148s] [(875, 'Zelimkhan Yandarbiyev', 'A Chechen writer and politician who served as President of the Chechen Republic of Ichkeria', 1, 'https://en.wikipedia.org/wiki/Zelimkhan_Yandarbiyev', nan, 1), (338, "Zarqawi's cause", 'Referring to the jihadist campaign led by Abu Musab al-Zarqawi, the leader of al-Qaeda in Iraq during the Iraq War.', 1, 'https://en.wikipedia.org/wiki/Abu_Musab_al-Zarqawi', nan, 1), (837, 'Yugoslavia', 'A historical country in Southeastern and Central Europe for most of the 20th century, until its dissolution in the early 1990s.', 2, 'https://en.wikipedia.org/wiki/Yugoslavia', nan, 1), (618, "YPG (People's Protection Units)", 'A Kurdish militia in Syria that controls a portion of Syrian territory and fought against ISIS.', 3, 'https://en.wikipedia.org/wiki/People%27s_Protection_Units', nan, 1), (434, 'Yemeni Tribalism', "The strong tribal culture within Yemen that significantly influences the country's social and political dynamics.", 4, 'https://en.wikipedia.org/wiki/Yemeni_Crisis_(2011–present)', nan, 1), (444, 'Yemeni Sectarian Landscape', 'The religious and sectarian divisions within Yemen, including various Islamic sects such as Sunnis, Zaidis, and Jarudi Zaidis.', 4, 'https://en.wikipedia.org/wiki/Religion_in_Yemen', nan, 1), (503, 'Yemeni Coast', 'The coastline of Yemen, which is strategically important due to its proximity to key shipping routes and the Bab-el-Mandeb Strait.', 5, 'https://en.wikipedia.org/wiki/Geography_of_Yemen', '14.4990, 46.3666', 1), (440, 'Yemeni AK-47 Culture', 'The widespread possession and cultural significance of AK-47s among civilians in Yemen.', 4, 'https://en.wikipedia.org/wiki/Yemeni_Crisis_(2011–present)', nan, 1)  ... displaying 10 of 422 total bound parameter sets ...  (913, '2008 Financial Crisis', 'A severe worldwide economic crisis that occurred in the late 2000s, related to the subprime mortgage market and financial instruments like derivatives.', 2, 'https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%932008', nan, 1), (64, '9/11', 'A series of coordinated terrorist attacks by the Islamist terrorist group al-Qaeda against the United States on the morning of Tuesday, September 11, 2001.', 8, 'https://en.wikipedia.org/wiki/September_11_attacks', nan, 1)]
# 2024-07-26 03:07:01,097 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-26 03:07:01,098 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-26 03:07:01,099 INFO sqlalchemy.engine.Engine INSERT INTO series (series_id, series_title, project_id) VALUES (?, ?, ?)
# 2024-07-26 03:07:01,099 INFO sqlalchemy.engine.Engine [generated in 0.00037s] (1, 'Conflicted Podcast', 1)
# 2024-07-26 03:07:01,100 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-26 03:07:01,101 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-26 03:07:01,101 INFO sqlalchemy.engine.Engine INSERT INTO segments (segment_id, segment_title, series_id, project_id) VALUES (?, ?, ?, ?)
# 2024-07-26 03:07:01,102 INFO sqlalchemy.engine.Engine [generated in 0.00024s] [(1, 'S1E1 - 9/11', 1, 1), (2, 'S1E2 - War on Terror', 1, 1), (3, 'S1E3 - Iraq', 1, 1), (4, 'S1E4 - Yemen', 1, 1), (5, 'S1E5 - Syria', 1, 1), (6, 'S1E6 - Returning Jihadists', 1, 1), (7, 'S2E1 - World War Iran', 1, 1), (8, 'S2E2 - New World Order', 1, 1)  ... displaying 10 of 51 total bound parameter sets ...  (50, "S4E18: Hezbollah: Israel's Menace or Lebanon's Defender?", 1, 1), (51, 'S4E19: Yemen: In the Shadow of the Imam', 1, 1)]
# 2024-07-26 03:07:01,103 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-26 03:07:01,143 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-26 03:07:01,174 INFO sqlalchemy.engine.Engine INSERT INTO elements (element_id, element_text, segment_id, project_id) VALUES (?, ?, ?, ?)
# 2024-07-26 03:07:01,174 INFO sqlalchemy.engine.Engine [generated in 0.01370s] [(7, "Thomas Small Let's get into it. ", 1, 1), (8, "We'll start this series with an event that catapulted the conflicts of the Middle East into the global consciousness: The Twin Tower attacks on September 11th. ", 1, 1), (9, 'Aimen Dean Okay.', 1, 1), (10, "Thomas Small Right. So, we're just starting. ", 1, 1), (11, 'Aimen Dean Yeah. Go ahead.', 1, 1), (12, "Thomas Small Aimen Dean. How do I introduce Aimen Dean? There is literally no one on Planet Earth like Aimen Dean. Saudi-born, but Bahraini nationali ... (904 characters truncated) ... s his former al-Qaeda – the surviving former al-Qaeda jihadists and their followers want to kill him dead for stabbing them in the back. Aimen Dean. ", 1, 1), (13, 'Aimen Dean Well, that was, you know, a rather ominous introduction. Well, Thomas, how am I going to introduce you? Even after years of knowing you—po ... (715 characters truncated) ... e nuances, the… Understand the Bedouin culture?\' You know, if I want to describe Thomas Small in few words, I would say that he is no small at all. ', 1, 1), (14, "Thomas Small Well, here's the thing, Aimen. I met you and I felt weirdly like I had met some kind of spiritual brother.", 1, 1)  ... displaying 10 of 12396 total bound parameter sets ...  (15609, 'There you will find other fans of the show engaging in heated debates, enlightening conversations, and just generally geeking out over Conflicted related topics.', 51, 1), (15610, 'Conflicted is a Message Heard production. This episode was produced and edited by Harry Stott. Sandra Ferrari is our executive producer. Our theme music is by Matt Huxley and Tom Biddle.', 51, 1)]
# 2024-07-26 03:07:01,194 INFO sqlalchemy.engine.Engine COMMIT
# 2024-07-26 03:07:01,202 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-26 03:07:01,215 INFO sqlalchemy.engine.Engine INSERT INTO annotations (annotation_id, element_id, code_id, project_id) VALUES (?, ?, ?, ?)
# 2024-07-26 03:07:01,215 INFO sqlalchemy.engine.Engine [generated in 0.00583s] [(0, 12, 12, 1), (1, 12, 35, 1), (2, 12, 42, 1), (3, 12, 70, 1), (4, 12, 381, 1), (5, 12, 60, 1), (6, 12, 48, 1), (7, 12, 725, 1)  ... displaying 10 of 5505 total bound parameter sets ...  (5503, 15603, 719, 1), (5504, 15606, 719, 1)]
# 2024-07-26 03:07:01,223 INFO sqlalchemy.engine.Engine COMMIT
# /var/folders/qf/j616b9d53yn77zcpky42s5r40000gn/T/ipykernel_51627/945524614.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   data: list[dict[Hashable, Any]] = df.to_dict(orient='records') # type: ignore

# %%
# Step 1: Select a random code item
random_code = session.query(Code).order_by(func.random()).first()

if random_code:
    code_id = random_code.code_id
    print("Random Code ID:")
    print(code_id)
    print("Random Code Item:")
    print(random_code)

    # Step 2: Find all annotations associated with the selected code
    annotations = session.query(Annotation).filter(Annotation.code_id == code_id).all()

    if annotations:
        print('----\nRESULTS\n-----')
        for annotation in annotations:
            print("\nAssociated Annotation:")
            print(annotation)

            # Step 3: Retrieve all elements associated with those annotations
            element_id = annotation.element_id
            element = session.query(Element).filter(Element.element_id == element_id).first()

            if element:
                print("\nAssociated Element:")
                print(element)
            else:
                print("No associated elements found.")
            print("\n")
            print("--------------------------------------------------")
            print("\n")
    else:
        print("No associated annotations found.")
else:
    print("No codes found in the database.")
# Out:
# 2024-07-26 03:07:01,229 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-07-26 03:07:01,231 INFO sqlalchemy.engine.Engine SELECT codes.code_id AS codes_code_id, codes.term AS codes_term, codes.description AS codes_description, codes.type_id AS codes_type_id, codes.reference AS codes_reference, codes.coordinates AS codes_coordinates, codes.project_id AS codes_project_id
# FROM codes ORDER BY random()
#  LIMIT ? OFFSET ?
# 2024-07-26 03:07:01,232 INFO sqlalchemy.engine.Engine [generated in 0.00051s] (1, 0)
# Random Code ID:
# 940
# Random Code Item:
# Code(code_id=940, term=Nairobi, description=The capital and largest city of Kenya, which has experienced terror attacks and may be a hub for monitoring terror financing, type_id=5, reference=https://en.wikipedia.org/wiki/Nairobi, coordinates=-1.286389, 36.817223, project_id=1)
# 2024-07-26 03:07:01,234 INFO sqlalchemy.engine.Engine SELECT annotations.annotation_id AS annotations_annotation_id, annotations.element_id AS annotations_element_id, annotations.code_id AS annotations_code_id, annotations.project_id AS annotations_project_id
# FROM annotations
# WHERE annotations.code_id = ?
# 2024-07-26 03:07:01,234 INFO sqlalchemy.engine.Engine [generated in 0.00039s] (940,)
# ----
# RESULTS
# -----
#
# Associated Annotation:
# Annotation(annotation_id=737, element_id=819, code_id=940)
# 2024-07-26 03:07:01,236 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id, elements.project_id AS elements_project_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-26 03:07:01,236 INFO sqlalchemy.engine.Engine [generated in 0.00049s] (819, 1, 0)
#
# Associated Element:
# Element(element_id=819, element_text=Aimen Dean No, of course not. I mean, I didn't see the American embassy in Nairobi, for example, pushing the siege towers towards Mecca and Medina. , segment_id=2)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=1833, element_id=3081, code_id=940)
# 2024-07-26 03:07:01,237 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id, elements.project_id AS elements_project_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-26 03:07:01,237 INFO sqlalchemy.engine.Engine [cached since 0.00167s ago] (3081, 1, 0)
#
# Associated Element:
# Element(element_id=3081, element_text=Aimen Dean Yes. But a minority. I still basically am a bit sceptical. I would say, basically, a minority can be rehabilitated, especially if they are, as, you know, as I was in the past, basically, and annoyingly inquisitive and a free thinker. You know, this is what needs to happen. You spot them. You see, basically, that there are people who think or themselves, who are, you know, willing to question what they've done. These are the people you should target. Those who stubbornly, stubbornly hold on to the animosity towards every society on earth, that's who you should isolate. I would accept individuals who want to come back if they just go and walk in into the British embassy in Ankara or in Nairobi or in Islamabad and declare, "I'm a walk-in. That's it. I want to renounce the group and everything that stands for." Whether it's al-Qaeda or ISIS or Taliban or al-Shabaab or whatever. If they do that, then that is actually a true willingness to abandon that path. , segment_id=6)
#
#
# --------------------------------------------------
#
#
#
# Associated Annotation:
# Annotation(annotation_id=2322, element_id=4315, code_id=940)
# 2024-07-26 03:07:01,238 INFO sqlalchemy.engine.Engine SELECT elements.element_id AS elements_element_id, elements.element_text AS elements_element_text, elements.segment_id AS elements_segment_id, elements.project_id AS elements_project_id
# FROM elements
# WHERE elements.element_id = ?
#  LIMIT ? OFFSET ?
# 2024-07-26 03:07:01,238 INFO sqlalchemy.engine.Engine [cached since 0.002579s ago] (4315, 1, 0)
#
# Associated Element:
# Element(element_id=4315, element_text=AIMEN: [Overlapping] Well Karachi, Manila, you know, in Nairobi in Kenya. So basically there are many places around the world, even places that you would think it is kind of benign, but nonetheless, there is a concentration of certain individuals there or certain activities there. Even in Bangkok for example. I mean, there are places that are famous like you know for people who unfortunately go and have, you know, inappropriate sexual relationship with young girls. So, you know…, segment_id=11)
#
#
# --------------------------------------------------
